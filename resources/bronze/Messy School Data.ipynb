-- %% [markdown]
-- # 00 — Messy School Data Generator
--
-- This notebook creates a set of **deliberately messy** tables in `catalog_40_copper_analyst_training.bronze` for use in the data modelling and standardisation exercises.
--
-- The data simulates termly snapshots of schools, pupils, enrolments, and assessments — each riddled with the data quality issues covered in notebooks 02–08:
--
-- * **Exact duplicates** — carbon-copy rows where every column is identical
-- * **Natural key duplicates** — same `pupil_id` within a snapshot but with conflicting values in other fields, requiring business rules to resolve
-- * **Metadata conflicts** — JSON `metadata_json` fields with extra or missing keys between duplicate rows (e.g. one row has `medical_notes`, the other doesn't; one has a `secondary_contact` block; one has `behaviour_log` entries). These force decisions about which row is "most complete" or "most authoritative"
-- * **Nested addresses** — each pupil has a top-level `address` (home) and each parent `contact` contains its own `address` (usually matching the pupil's). For **P011 (Katie Jones)** the mother's contact address matches the pupil's Canterbury home, but the father's duplicate row has a different parent address in Maidstone — a divorced-parents scenario that forces a "which contact is primary?" decision
-- * **Address changes** — **P004 (Dan Brown)** moves from Birmingham to Bristol between autumn 2024 and spring 2025 when his school (Birch College) closes, demonstrating how addresses track with school moves
-- * **Inconsistent labels** — case differences, whitespace, abbreviations
-- * **Schema drift** — column names differ between snapshots
-- * **Orphaned foreign keys** — references to schools/pupils that don't exist
-- * **Null handling** — mix of `NULL`, empty strings, and placeholder values
-- * **Date format inconsistencies**
--
-- ### Natural key conflict scenarios across pupil snapshots
--
-- | Snapshot | Pupil | Conflict type |
-- | --- | --- | --- |
-- | Autumn 2024 | P002 | Name variant (Bob vs Robert) + different email |
-- | Autumn 2024 | P005 | `fsm_eligible` flipped + extra `medical_notes` |
-- | Autumn 2024 | P008 | SEN status downgraded (EHCP → SEN Support) + `annual_review_date` |
-- | Autumn 2024 | P011 | Different parent contact (mother vs father) + **different parent address** |
-- | Autumn 2024 | P014 | Extra `exclusions` and `behaviour_notes` fields |
-- | Spring 2025 | P003 | Conflicting `attendance_pct` + `allergy_info` |
-- | Spring 2025 | P007 | `fsm_eligible` flipped + `dietary_requirements` |
-- | Spring 2025 | P015 | SEN status changed + `learning_support_plan` |
-- | Spring 2025 | P017 | Different parent phone + `secondary_contact` block |
-- | Summer 2025 | P002 | Updated email + `behaviour_log` array |
-- | Summer 2025 | P009 | `fsm_eligible` flipped + `medical_notes` |
-- | Summer 2025 | P013 | Conflicting `attendance_pct` + `assessment_notes` |
-- | Summer 2025 | P020 | SEN status conflict + `fsm_eligible` conflict |
-- | Autumn 2025 | P006 | `fsm_eligible` flipped + `behaviour_notes` |
-- | Autumn 2025 | P010 | SEN status removed + `sen_review_notes` |
-- | Autumn 2025 | P016 | Different primary parent + `secondary_contact` block |
-- | Autumn 2025 | P022 | SEN status added + `learning_support` field |
--
-- Run all cells in order to (re)create the schema and tables.

-- %%
%sql
USE CATALOG catalog_40_copper_analyst_training;

-- %%
-- Schools snapshot: Autumn 2024
-- Issues: inconsistent casing, whitespace, abbreviations, NULL vs empty string, duplicate URNs
CREATE OR REPLACE TABLE bronze.schools_autumn_2024 AS
SELECT * FROM VALUES
  -- Clean records
  (100001, 'Oak Academy',           'London',       'Academy',    'Open',   'Secondary', '{"ofsted_rating": "Good", "last_inspection": "2023-06-15"}'),
  (100002, 'Elm Community School',  'Manchester',   'Maintained', 'Open',   'Primary',   '{"ofsted_rating": "Outstanding", "last_inspection": "2022-11-20"}'),
  (100003, 'Birch College',         'Birmingham',   'Academy',    'Open',   'Secondary', '{"ofsted_rating": "Requires Improvement", "last_inspection": "2024-01-10"}'),
  (100004, 'Cedar Primary',         'Leeds',        'Maintained', 'Open',   'Primary',   '{"ofsted_rating": "Good", "last_inspection": "2023-09-05"}'),
  (100005, 'Willow Park School',    'Bristol',      'Academy',    'Open',   'Secondary', '{"ofsted_rating": "Good", "last_inspection": "2023-03-22"}'),
  -- Inconsistent casing and whitespace
  (100006, 'maple grove primary',   'SHEFFIELD',    'maintained', 'Open',   'primary',   '{"ofsted_rating": "Good", "last_inspection": "2023-07-01"}'),
  (100007, ' Ash Valley School ',   'liverpool',    'Academy',    'open',   'Secondary', '{"ofsted_rating": "Inadequate", "last_inspection": "2024-02-28"}'),
  (100008, 'Pine Hills Acad.',      'London',       'Acad',       'Open',   'Sec',       '{"ofsted_rating": "Good", "last_inspection": "2023-11-15"}'),
  -- NULL and empty string inconsistencies
  (100009, 'Rowan Free School',     'Nottingham',   'Free School','Open',   '',          '{"ofsted_rating": null, "last_inspection": null}'),
  (100010, 'Hazel Grammar',         '',             'Academy',    'Open',   NULL,        '{"ofsted_rating": "Good"}'),
  (100011, 'Ivy Technical College', NULL,           'N/A',        'Unknown','Secondary', NULL),
  -- Exact duplicate
  (100001, 'Oak Academy',           'London',       'Academy',    'Open',   'Secondary', '{"ofsted_rating": "Good", "last_inspection": "2023-06-15"}'),
  -- Same URN, different data (natural key duplicate)
  (100005, 'Willow Park Academy',   'Bristol',      'Academy',    'Open',   'Secondary', '{"ofsted_rating": "Outstanding", "last_inspection": "2024-03-01"}'),
  -- Additional schools for volume
  (100012, 'Sycamore High',         'Newcastle',    'Academy',    'Open',   'Secondary', '{"ofsted_rating": "Good", "last_inspection": "2023-05-20"}'),
  (100013, 'Poplar Lane Primary',   'Oxford',       'Maintained', 'Open',   'Primary',   '{"ofsted_rating": "Outstanding", "last_inspection": "2022-09-14"}'),
  (100014, 'Yew Tree School',       'Cambridge',    'Academy',    'Open',   'All-through','{"ofsted_rating": "Good", "last_inspection": "2023-08-30"}'),
  (100015, 'Laurel Park Academy',   'Bath',         'Academy',    'Open',   'Secondary', '{"ofsted_rating": "Requires Improvement", "last_inspection": "2024-01-22"}'),
  (100016, 'Holly Cross School',    'York',         'Maintained', 'Open',   'Primary',   '{"ofsted_rating": "Good", "last_inspection": "2023-04-11"}'),
  (100017, 'Juniper Academy',       'Plymouth',     'Academy',    'Open',   'Secondary', '{"ofsted_rating": "Good", "last_inspection": "2023-12-05"}'),
  (100018, 'Alder Community School','Coventry',     'Maintained', 'Open',   'Primary',   '{"ofsted_rating": "Inadequate", "last_inspection": "2024-02-15"}')
AS t(school_urn, school_name, city, school_type, status, phase, metadata_json);

-- %%
-- Schools snapshot: Spring 2025
-- Issues: DIFFERENT COLUMN NAMES (schema drift), more inconsistencies, a closed school, orphan-inducing gaps
CREATE OR REPLACE TABLE bronze.schools_spring_2025 AS
SELECT * FROM VALUES
  -- Note: column names differ from autumn! 'establishment_name' not 'school_name', 'local_authority' not 'city', 'phase_of_education' not 'phase'
  (100001, 'Oak Academy',           'London',       'Academy',     'Open',   'Secondary', '{"ofsted_rating": "Good", "last_inspection": "2023-06-15", "pupil_premium_pct": 0.32}'),
  (100002, 'Elm Community School',  'Manchester',   'Maintained',  'Open',   'Primary',   '{"ofsted_rating": "Outstanding", "last_inspection": "2022-11-20", "pupil_premium_pct": 0.18}'),
  (100003, 'Birch College',         'Birmingham',   'Academy',     'Closed', 'Secondary', '{"ofsted_rating": "Requires Improvement", "last_inspection": "2024-01-10", "pupil_premium_pct": 0.45}'),
  (100004, 'Cedar Primary School',  'Leeds',        'Maintained',  'Open',   'Primary',   '{"ofsted_rating": "Good", "last_inspection": "2023-09-05", "pupil_premium_pct": 0.27}'),
  (100005, 'Willow Park School',    'Bristol',      'Academy',     'Open',   'Secondary', '{"ofsted_rating": "Outstanding", "last_inspection": "2024-03-01", "pupil_premium_pct": 0.21}'),
  (100006, 'Maple Grove Primary',   'Sheffield',    'Maintained',  'Open',   'Primary',   '{"ofsted_rating": "Good", "last_inspection": "2023-07-01", "pupil_premium_pct": 0.38}'),
  (100007, 'Ash Valley School',     'Liverpool',    'Academy',     'Open',   'Secondary', '{"ofsted_rating": "Good", "last_inspection": "2024-09-10", "pupil_premium_pct": 0.29}'),
  (100008, 'Pine Hills Academy',    'London',       'Academy',     'Open',   'Secondary', '{"ofsted_rating": "Good", "last_inspection": "2023-11-15", "pupil_premium_pct": 0.15}'),
  (100009, 'Rowan Free School',     'Nottingham',   'Free School', 'Open',   'All-through','{"ofsted_rating": "Good", "last_inspection": "2024-07-20", "pupil_premium_pct": 0.22}'),
  (100010, 'Hazel Grammar School',  'Canterbury',   'Academy',     'Open',   'Secondary', '{"ofsted_rating": "Good", "last_inspection": "2024-05-12", "pupil_premium_pct": 0.09}'),
  -- 100011 Ivy Technical College is MISSING from this snapshot entirely
  (100012, 'sycamore high',         'newcastle',    'academy',     'Open',   'secondary', '{"ofsted_rating": "Good", "last_inspection": "2023-05-20", "pupil_premium_pct": 0.33}'),
  (100013, 'Poplar Lane Primary',   'Oxford',       'Maintained',  'Open',   'Primary',   '{"ofsted_rating": "Outstanding", "last_inspection": "2022-09-14", "pupil_premium_pct": 0.12}'),
  (100014, 'Yew Tree School',       'Cambridge',    'Academy',     'Open',   'All-through','{"ofsted_rating": "Good", "last_inspection": "2023-08-30", "pupil_premium_pct": 0.20}'),
  (100015, 'Laurel Park Academy',   'Bath',         'Academy',     'Open',   'Secondary', '{"ofsted_rating": "Good", "last_inspection": "2024-11-05", "pupil_premium_pct": 0.41}'),
  (100016, 'Holly Cross School',    'York',         'Maintained',  'Open',   'Primary',   '{"ofsted_rating": "Good", "last_inspection": "2023-04-11", "pupil_premium_pct": 0.35}'),
  (100017, 'Juniper Academy',       'Plymouth',     'Academy',     'Open',   'Secondary', '{"ofsted_rating": "Good", "last_inspection": "2023-12-05", "pupil_premium_pct": 0.24}'),
  (100018, 'Alder Community School','Coventry',     'Maintained',  'Open',   'Primary',   '{"ofsted_rating": "Good", "last_inspection": "2024-08-15", "pupil_premium_pct": 0.48}'),
  -- New school not in autumn snapshot
  (100019, 'Chestnut Academy',      'Reading',      'Academy',     'Open',   'Secondary', '{"ofsted_rating": null, "last_inspection": null, "pupil_premium_pct": null}')
AS t(urn, establishment_name, local_authority, establishment_type, status, phase_of_education, metadata_json);

-- %%
-- Schools snapshot: Summer 2025
-- Issues: NEW COLUMN 'region' added, inconsistent region casing, NULL region values
-- Retains spring column names (urn, establishment_name, local_authority, etc.)
CREATE OR REPLACE TABLE bronze.schools_summer_2025 AS
SELECT * FROM VALUES
  (100001, 'Oak Academy',           'London',       'Academy',     'Open',   'Secondary',   'London',          '{"ofsted_rating": "Good", "last_inspection": "2025-05-12", "pupil_premium_pct": 0.30}'),
  (100002, 'Elm Community School',  'Manchester',   'Maintained',  'Open',   'Primary',     'North West',      '{"ofsted_rating": "Outstanding", "last_inspection": "2022-11-20", "pupil_premium_pct": 0.18}'),
  (100003, 'Birch College',         'Birmingham',   'Academy',     'Closed', 'Secondary',   'West Midlands',   '{"ofsted_rating": "Requires Improvement", "last_inspection": "2024-01-10", "pupil_premium_pct": 0.45}'),
  (100004, 'Cedar Primary School',  'Leeds',        'Maintained',  'Open',   'Primary',     'Yorkshire',       '{"ofsted_rating": "Good", "last_inspection": "2023-09-05", "pupil_premium_pct": 0.27}'),
  (100005, 'Willow Park School',    'Bristol',      'Academy',     'Open',   'Secondary',   'South West',      '{"ofsted_rating": "Outstanding", "last_inspection": "2024-03-01", "pupil_premium_pct": 0.21}'),
  (100006, 'Maple Grove Primary',   'Sheffield',    'Maintained',  'Open',   'Primary',     'Yorkshire',       '{"ofsted_rating": "Good", "last_inspection": "2023-07-01", "pupil_premium_pct": 0.38}'),
  (100007, 'Ash Valley School',     'Liverpool',    'Academy',     'Open',   'Secondary',   'North West',      '{"ofsted_rating": "Good", "last_inspection": "2024-09-10", "pupil_premium_pct": 0.29}'),
  (100008, 'Pine Hills Academy',    'London',       'Academy',     'Open',   'Secondary',   'London',          '{"ofsted_rating": "Good", "last_inspection": "2023-11-15", "pupil_premium_pct": 0.15}'),
  (100009, 'Rowan Free School',     'Nottingham',   'Free School', 'Open',   'All-through', 'East Midlands',   '{"ofsted_rating": "Good", "last_inspection": "2024-07-20", "pupil_premium_pct": 0.22}'),
  (100010, 'Hazel Grammar School',  'Canterbury',   'Academy',     'Open',   'Secondary',   'South East',      '{"ofsted_rating": "Good", "last_inspection": "2024-05-12", "pupil_premium_pct": 0.09}'),
  -- Inconsistent region casing
  (100012, 'Sycamore High',         'Newcastle',    'Academy',     'Open',   'Secondary',   'north east',      '{"ofsted_rating": "Good", "last_inspection": "2023-05-20", "pupil_premium_pct": 0.33}'),
  (100013, 'Poplar Lane Primary',   'Oxford',       'Maintained',  'Open',   'Primary',     'South East',      '{"ofsted_rating": "Outstanding", "last_inspection": "2022-09-14", "pupil_premium_pct": 0.12}'),
  (100014, 'Yew Tree School',       'Cambridge',    'Academy',     'Open',   'All-through', 'east of england', '{"ofsted_rating": "Good", "last_inspection": "2023-08-30", "pupil_premium_pct": 0.20}'),
  (100015, 'Laurel Park Academy',   'Bath',         'Academy',     'Open',   'Secondary',   'South West',      '{"ofsted_rating": "Good", "last_inspection": "2024-11-05", "pupil_premium_pct": 0.41}'),
  (100016, 'Holly Cross School',    'York',         'Maintained',  'Open',   'Primary',     'Yorkshire',       '{"ofsted_rating": "Good", "last_inspection": "2023-04-11", "pupil_premium_pct": 0.35}'),
  (100017, 'Juniper Academy',       'Plymouth',     'Academy',     'Open',   'Secondary',   'South West',      '{"ofsted_rating": "Good", "last_inspection": "2023-12-05", "pupil_premium_pct": 0.24}'),
  (100018, 'Alder Community School','Coventry',     'Maintained',  'Open',   'Primary',     'West Midlands',   '{"ofsted_rating": "Good", "last_inspection": "2025-03-20", "pupil_premium_pct": 0.44}'),
  (100019, 'Chestnut Academy',      'Reading',      'Academy',     'Open',   'Secondary',   'South East',      '{"ofsted_rating": "Good", "last_inspection": "2025-06-01", "pupil_premium_pct": 0.17}'),
  -- NULL and empty region values
  (100020, 'Beech Park School',     'Brighton',     'Free School', 'Open',   'Primary',     NULL,              '{"ofsted_rating": null, "last_inspection": null, "pupil_premium_pct": null}'),
  (100021, 'Larch Gate Academy',    'Exeter',       'Academy',     'Open',   'Secondary',   '',                '{"ofsted_rating": null, "last_inspection": null, "pupil_premium_pct": null}')
AS t(urn, establishment_name, local_authority, establishment_type, status, phase_of_education, region, metadata_json);

-- %%
-- Schools snapshot: Autumn 2025
-- Issues: COLUMN REMOVED — phase/phase_of_education is no longer in the extract
-- Schema drifts back to autumn-style column names (school_urn, school_name, city, etc.)
-- 100003 (Birch College) removed entirely after closure, 100011 still missing
CREATE OR REPLACE TABLE bronze.schools_autumn_2025 AS
SELECT * FROM VALUES
  (100001, 'Oak Academy',           'London',       'Academy',     'Open',   '{"ofsted_rating": "Good", "last_inspection": "2025-05-12", "pupil_premium_pct": 0.30}'),
  (100002, 'Elm Community School',  'Manchester',   'Maintained',  'Open',   '{"ofsted_rating": "Outstanding", "last_inspection": "2025-09-15", "pupil_premium_pct": 0.16}'),
  (100004, 'Cedar Primary',         'Leeds',        'Maintained',  'Open',   '{"ofsted_rating": "Good", "last_inspection": "2023-09-05", "pupil_premium_pct": 0.27}'),
  (100005, 'Willow Park School',    'Bristol',      'Academy',     'Open',   '{"ofsted_rating": "Outstanding", "last_inspection": "2024-03-01", "pupil_premium_pct": 0.19}'),
  (100006, 'Maple Grove Primary',   'Sheffield',    'Maintained',  'Open',   '{"ofsted_rating": "Good", "last_inspection": "2023-07-01", "pupil_premium_pct": 0.38}'),
  (100007, 'Ash Valley School',     'Liverpool',    'Academy',     'Open',   '{"ofsted_rating": "Good", "last_inspection": "2024-09-10", "pupil_premium_pct": 0.29}'),
  (100008, 'Pine Hills Academy',    'London',       'Academy',     'Open',   '{"ofsted_rating": "Good", "last_inspection": "2023-11-15", "pupil_premium_pct": 0.15}'),
  (100009, 'Rowan Free School',     'Nottingham',   'Free School', 'Open',   '{"ofsted_rating": "Good", "last_inspection": "2024-07-20", "pupil_premium_pct": 0.22}'),
  (100010, 'Hazel Grammar',         'Canterbury',   'Academy',     'Open',   '{"ofsted_rating": "Good", "last_inspection": "2024-05-12", "pupil_premium_pct": 0.09}'),
  -- Inconsistent casing
  (100012, 'sycamore high',         'NEWCASTLE',    'academy',     'Open',   '{"ofsted_rating": "Good", "last_inspection": "2025-07-14", "pupil_premium_pct": 0.31}'),
  (100013, 'Poplar Lane Primary',   'Oxford',       'Maintained',  'Open',   '{"ofsted_rating": "Outstanding", "last_inspection": "2022-09-14", "pupil_premium_pct": 0.12}'),
  (100014, 'Yew Tree School',       'Cambridge',    'Academy',     'Open',   '{"ofsted_rating": "Good", "last_inspection": "2023-08-30", "pupil_premium_pct": 0.20}'),
  (100015, 'Laurel Park Academy',   'Bath',         'Academy',     'Open',   '{"ofsted_rating": "Good", "last_inspection": "2024-11-05", "pupil_premium_pct": 0.39}'),
  (100016, 'Holly Cross School',    'York',         'Maintained',  'Open',   '{"ofsted_rating": "Good", "last_inspection": "2023-04-11", "pupil_premium_pct": 0.35}'),
  (100017, 'Juniper Academy',       'Plymouth',     'Academy',     'Open',   '{"ofsted_rating": "Good", "last_inspection": "2023-12-05", "pupil_premium_pct": 0.24}'),
  (100018, 'Alder Community School','Coventry',     'Maintained',  'Open',   '{"ofsted_rating": "Good", "last_inspection": "2025-03-20", "pupil_premium_pct": 0.44}'),
  (100019, 'Chestnut Academy',      'Reading',      'Academy',     'Open',   '{"ofsted_rating": "Good", "last_inspection": "2025-06-01", "pupil_premium_pct": 0.17}'),
  (100020, 'Beech Park School',     'Brighton',     'Free School', 'Open',   '{"ofsted_rating": "Requires Improvement", "last_inspection": "2025-10-08", "pupil_premium_pct": 0.28}'),
  (100021, 'Larch Gate Academy',    'Exeter',       'Academy',     'Open',   '{"ofsted_rating": "Good", "last_inspection": "2025-11-01", "pupil_premium_pct": 0.22}'),
  -- Exact duplicate
  (100001, 'Oak Academy',           'London',       'Academy',     'Open',   '{"ofsted_rating": "Good", "last_inspection": "2025-05-12", "pupil_premium_pct": 0.30}')
AS t(school_urn, school_name, city, school_type, status, metadata_json);

-- %%
-- Pupils snapshot: Autumn 2024
-- Issues: duplicates, inconsistent names, mixed date formats, orphaned school refs, JSON with nested contact info
-- Natural key duplicates have conflicting metadata to demonstrate business rule decisions
-- Each pupil has an address, and each parent contact has an address (usually matching the pupil's)
CREATE OR REPLACE TABLE bronze.pupils_autumn_2024 AS

WITH base_pupils AS (
  SELECT * FROM VALUES
    -- Clean records at various schools
    ('P001', 'Alice',   'Johnson',   'F', '2012-03-15', 100001, 'Year 7',  '{"address": {"line1": "14 Maple Road", "city": "London", "postcode": "E1 6AN"}, "contact": {"parent_name": "Sarah Johnson", "phone": "07700900001", "email": "s.johnson@email.com", "address": {"line1": "14 Maple Road", "city": "London", "postcode": "E1 6AN"}}, "sen_status": "None", "fsm_eligible": false}'),
    ('P002', 'Bob',     'Smith',     'M', '2011-07-22', 100001, 'Year 8',  '{"address": {"line1": "7 Cedar Close", "city": "London", "postcode": "N1 3PQ"}, "contact": {"parent_name": "David Smith", "phone": "07700900002", "email": "d.smith@email.com", "address": {"line1": "7 Cedar Close", "city": "London", "postcode": "N1 3PQ"}}, "sen_status": "SEN Support", "fsm_eligible": true}'),
    ('P003', 'Carol',   'Williams',  'F', '2012-11-01', 100002, 'Year 7',  '{"address": {"line1": "23 Birch Lane", "city": "Manchester", "postcode": "M4 1HJ"}, "contact": {"parent_name": "Jane Williams", "phone": "07700900003", "email": "j.williams@email.com", "address": {"line1": "23 Birch Lane", "city": "Manchester", "postcode": "M4 1HJ"}}, "sen_status": "None", "fsm_eligible": false}'),
    ('P004', 'Dan',     'Brown',     'M', '2010-09-30', 100003, 'Year 9',  '{"address": {"line1": "9 Elm Drive", "city": "Birmingham", "postcode": "B15 2TT"}, "contact": {"parent_name": "Mike Brown", "phone": "07700900004", "address": {"line1": "9 Elm Drive", "city": "Birmingham", "postcode": "B15 2TT"}}, "sen_status": "EHCP", "fsm_eligible": true}'),
    ('P005', 'Eve',     'Taylor',    'F', '2013-01-18', 100004, 'Year 6',  '{"address": {"line1": "45 Willow Way", "city": "Leeds", "postcode": "LS1 4DY"}, "contact": {"parent_name": "Lisa Taylor", "phone": "07700900005", "email": "l.taylor@email.com", "address": {"line1": "45 Willow Way", "city": "Leeds", "postcode": "LS1 4DY"}}, "sen_status": "None", "fsm_eligible": false}'),
    ('P006', 'Frank',   'Davies',    'M', '2011-05-25', 100005, 'Year 8',  '{"address": {"line1": "18 Hawthorn Street", "city": "Bristol", "postcode": "BS2 8NJ"}, "contact": {"parent_name": "Helen Davies", "phone": "07700900006", "address": {"line1": "18 Hawthorn Street", "city": "Bristol", "postcode": "BS2 8NJ"}}, "sen_status": "SEN Support", "fsm_eligible": false}'),
    ('P007', 'Grace',   'Evans',     'F', '2012-08-12', 100006, 'Year 7',  '{"address": {"line1": "6 Rosemary Gardens", "city": "Sheffield", "postcode": "S1 2FP"}, "contact": {"parent_name": "Tom Evans", "phone": "07700900007", "email": "t.evans@email.com", "address": {"line1": "6 Rosemary Gardens", "city": "Sheffield", "postcode": "S1 2FP"}}, "sen_status": "None", "fsm_eligible": true}'),
    ('P008', 'Harry',   'Wilson',    'M', '2010-12-03', 100007, 'Year 9',  '{"address": {"line1": "52 Lime Avenue", "city": "Liverpool", "postcode": "L3 9DA"}, "contact": {"parent_name": "Claire Wilson", "address": {"line1": "52 Lime Avenue", "city": "Liverpool", "postcode": "L3 9DA"}}, "sen_status": "EHCP", "fsm_eligible": true}'),
    ('P009', 'Isla',    'Thomas',    'F', '2013-04-07', 100008, 'Year 6',  '{"address": {"line1": "3 Chestnut Terrace", "city": "London", "postcode": "SE1 7RG"}, "contact": {"parent_name": "Paul Thomas", "phone": "07700900009", "email": "p.thomas@email.com", "address": {"line1": "3 Chestnut Terrace", "city": "London", "postcode": "SE1 7RG"}}, "sen_status": "None", "fsm_eligible": false}'),
    ('P010', 'Jack',    'Roberts',   'M', '2011-10-19', 100009, 'Year 8',  '{"address": {"line1": "28 Ash Grove", "city": "Nottingham", "postcode": "NG1 5LL"}, "contact": {"parent_name": "Karen Roberts", "phone": "07700900010", "address": {"line1": "28 Ash Grove", "city": "Nottingham", "postcode": "NG1 5LL"}}, "sen_status": "SEN Support", "fsm_eligible": true}'),
    -- Inconsistent casing and name variants
    ('P011', 'katie',   'JONES',     'F', '2012-06-28', 100010, 'Year 7',  '{"address": {"line1": "11 Ivy Crescent", "city": "Canterbury", "postcode": "CT1 2XB"}, "contact": {"parent_name": "Emma Jones", "phone": "07700900011", "address": {"line1": "11 Ivy Crescent", "city": "Canterbury", "postcode": "CT1 2XB"}}, "sen_status": "None", "fsm_eligible": false}'),
    ('P012', 'LIAM',    'garcia',    'M', '15/02/2011', 100012, 'Yr 8',    '{"address": {"line1": "16 Pine Close", "city": "Newcastle", "postcode": "NE1 4RT"}, "contact": {"parent_name": "Maria Garcia", "address": {"line1": "16 Pine Close", "city": "Newcastle", "postcode": "NE1 4RT"}}, "sen_status": "none", "fsm_eligible": false}'),
    ('P013', 'Mia',     'Anderson',  'F', '03-22-2013', 100013, 'year 6',  '{"address": {"line1": "39 Beech Road", "city": "Oxford", "postcode": "OX1 3SG"}, "contact": {"parent_name": "Chris Anderson", "phone": "07700900013", "email": "c.anderson@email.com", "address": {"line1": "39 Beech Road", "city": "Oxford", "postcode": "OX1 3SG"}}, "sen_status": "None", "fsm_eligible": true}'),
    ('P014', 'Noah',    'Martinez',  'M', '2010-11-14', 100014, 'Year 9',  '{"address": {"line1": "22 Laurel Street", "city": "Cambridge", "postcode": "CB1 2HU"}, "contact": {"parent_name": "Ana Martinez", "phone": "07700900014", "address": {"line1": "22 Laurel Street", "city": "Cambridge", "postcode": "CB1 2HU"}}, "sen_status": "SEN Support", "fsm_eligible": false}'),
    ('P015', 'Olivia',  'Lee',       'F', '2012-02-09', 100015, 'Year 7',  '{"address": {"line1": "8 Juniper Way", "city": "Bath", "postcode": "BA1 3NE"}, "contact": {"parent_name": "James Lee", "phone": "07700900015", "email": "j.lee@email.com", "address": {"line1": "8 Juniper Way", "city": "Bath", "postcode": "BA1 3NE"}}, "sen_status": "None", "fsm_eligible": false}'),
    ('P016', 'Peter',   'Clark',     'M', '2011-08-17', 100016, 'Year 8',  '{"address": {"line1": "55 Rowan Drive", "city": "York", "postcode": "YO1 6BW"}, "contact": {"parent_name": "Susan Clark", "phone": "07700900016", "address": {"line1": "55 Rowan Drive", "city": "York", "postcode": "YO1 6BW"}}, "sen_status": "None", "fsm_eligible": true}'),
    ('P017', 'Quinn',   'Lewis',     'F', '2013-07-03', 100017, 'Year 6',  '{"address": {"line1": "12 Holly Lane", "city": "Plymouth", "postcode": "PL1 4DX"}, "contact": {"parent_name": "Robert Lewis", "phone": "07700900017", "email": "r.lewis@email.com", "address": {"line1": "12 Holly Lane", "city": "Plymouth", "postcode": "PL1 4DX"}}, "sen_status": "EHCP", "fsm_eligible": true}'),
    ('P018', 'Ryan',    'Walker',    'M', '2010-04-26', 100018, 'Year 9',  '{"address": {"line1": "34 Poplar Avenue", "city": "Coventry", "postcode": "CV1 5FG"}, "contact": {"parent_name": "Michelle Walker", "address": {"line1": "34 Poplar Avenue", "city": "Coventry", "postcode": "CV1 5FG"}}, "sen_status": "None", "fsm_eligible": false}'),
    -- Orphaned foreign key: school 999999 doesn''t exist
    ('P019', 'Sophie',  'Hall',      'F', '2012-09-11', 999999, 'Year 7',  '{"address": {"line1": "19 Alder Close", "city": "London", "postcode": "SW1 8QR"}, "contact": {"parent_name": "Mark Hall", "phone": "07700900019", "address": {"line1": "19 Alder Close", "city": "London", "postcode": "SW1 8QR"}}, "sen_status": "None", "fsm_eligible": false}'),
    -- NULL and empty gender/year group
    ('P020', 'Tom',     'Wright',    'M', '2011-03-08', 100001, '',        '{"address": {"line1": "41 Sycamore Road", "city": "London", "postcode": "E2 0PL"}, "contact": {"parent_name": "Linda Wright", "address": {"line1": "41 Sycamore Road", "city": "London", "postcode": "E2 0PL"}}, "sen_status": "Unknown", "fsm_eligible": null}'),
    ('P021', 'Uma',     'Young',     NULL,'2013-12-25', 100002, 'Year 6',  '{"address": {"line1": "5 Yew Tree Lane", "city": "Manchester", "postcode": "M3 4JK"}, "contact": {}, "sen_status": null, "fsm_eligible": false}'),
    ('P022', 'Victor',  'King',      'M', NULL,         100005, 'Year 8',  '{"address": {"line1": "27 Hazel Court", "city": "Bristol", "postcode": "BS3 1RT"}, "contact": {"parent_name": "Janet King", "phone": "07700900022", "address": {"line1": "27 Hazel Court", "city": "Bristol", "postcode": "BS3 1RT"}}, "sen_status": "N/A", "fsm_eligible": false}'),
    -- Additional pupils for volume
    ('P027', 'Amber',   'Mitchell',  'F', '2012-05-14', 100002, 'Year 7',  '{"address": {"line1": "17 Primrose Lane", "city": "Manchester", "postcode": "M5 2DA"}, "contact": {"parent_name": "Laura Mitchell", "phone": "07700900027", "email": "l.mitchell@email.com", "address": {"line1": "17 Primrose Lane", "city": "Manchester", "postcode": "M5 2DA"}}, "sen_status": "None", "fsm_eligible": false}'),
    ('P028', 'Ben',     'Cooper',    'M', '2011-01-30', 100006, 'Year 8',  '{"address": {"line1": "44 Bluebell Way", "city": "Sheffield", "postcode": "S3 7HN"}, "contact": {"parent_name": "Gary Cooper", "phone": "07700900028", "address": {"line1": "44 Bluebell Way", "city": "Sheffield", "postcode": "S3 7HN"}}, "sen_status": "SEN Support", "fsm_eligible": true}'),
    ('P029', 'Chloe',   'Murphy',    'F', '2013-02-11', 100014, 'Year 6',  '{"address": {"line1": "10 Foxglove Road", "city": "Cambridge", "postcode": "CB2 1TP"}, "contact": {"parent_name": "Fiona Murphy", "phone": "07700900029", "email": "f.murphy@email.com", "address": {"line1": "10 Foxglove Road", "city": "Cambridge", "postcode": "CB2 1TP"}}, "sen_status": "None", "fsm_eligible": false}'),
    -- Exact duplicates (carbon copies — every column identical)
    ('P001', 'Alice',   'Johnson',   'F', '2012-03-15', 100001, 'Year 7',  '{"address": {"line1": "14 Maple Road", "city": "London", "postcode": "E1 6AN"}, "contact": {"parent_name": "Sarah Johnson", "phone": "07700900001", "email": "s.johnson@email.com", "address": {"line1": "14 Maple Road", "city": "London", "postcode": "E1 6AN"}}, "sen_status": "None", "fsm_eligible": false}'),
    ('P006', 'Frank',   'Davies',    'M', '2011-05-25', 100005, 'Year 8',  '{"address": {"line1": "18 Hawthorn Street", "city": "Bristol", "postcode": "BS2 8NJ"}, "contact": {"parent_name": "Helen Davies", "phone": "07700900006", "address": {"line1": "18 Hawthorn Street", "city": "Bristol", "postcode": "BS2 8NJ"}}, "sen_status": "SEN Support", "fsm_eligible": false}'),
    -- Natural key duplicate: same pupil_id, different first_name and updated email
    ('P002', 'Robert',  'Smith',     'M', '2011-07-22', 100001, 'Year 8',  '{"address": {"line1": "7 Cedar Close", "city": "London", "postcode": "N1 3PQ"}, "contact": {"parent_name": "David Smith", "phone": "07700900002", "email": "bob.smith@newemail.com", "address": {"line1": "7 Cedar Close", "city": "London", "postcode": "N1 3PQ"}}, "sen_status": "SEN Support", "fsm_eligible": true}'),
    -- Natural key duplicate: P005 — fsm_eligible flipped, extra medical_notes field in JSON
    ('P005', 'Eve',     'Taylor',    'F', '2013-01-18', 100004, 'Year 6',  '{"address": {"line1": "45 Willow Way", "city": "Leeds", "postcode": "LS1 4DY"}, "contact": {"parent_name": "Lisa Taylor", "phone": "07700900005", "email": "l.taylor@email.com", "address": {"line1": "45 Willow Way", "city": "Leeds", "postcode": "LS1 4DY"}}, "sen_status": "None", "fsm_eligible": true, "medical_notes": "Asthma - carries inhaler"}'),
    -- Natural key duplicate: P008 — SEN status downgraded, extra annual_review_date field
    ('P008', 'Harry',   'Wilson',    'M', '2010-12-03', 100007, 'Year 9',  '{"address": {"line1": "52 Lime Avenue", "city": "Liverpool", "postcode": "L3 9DA"}, "contact": {"parent_name": "Claire Wilson", "address": {"line1": "52 Lime Avenue", "city": "Liverpool", "postcode": "L3 9DA"}}, "sen_status": "SEN Support", "fsm_eligible": true, "annual_review_date": "2024-11-15"}'),
    -- Natural key duplicate: P011 — proper casing, different parent contact (father vs mother), DIFFERENT parent address
    ('P011', 'Katie',   'Jones',     'F', '2012-06-28', 100010, 'Year 7',  '{"address": {"line1": "11 Ivy Crescent", "city": "Canterbury", "postcode": "CT1 2XB"}, "contact": {"parent_name": "David Jones", "phone": "07700900099", "email": "d.jones@email.com", "address": {"line1": "87 Oak Lane", "city": "Maidstone", "postcode": "ME14 5HQ"}}, "sen_status": "None", "fsm_eligible": false}'),
    -- Natural key duplicate: P014 — extra exclusion and behaviour fields in JSON
    ('P014', 'Noah',    'Martinez',  'M', '2010-11-14', 100014, 'Year 9',  '{"address": {"line1": "22 Laurel Street", "city": "Cambridge", "postcode": "CB1 2HU"}, "contact": {"parent_name": "Ana Martinez", "phone": "07700900014", "address": {"line1": "22 Laurel Street", "city": "Cambridge", "postcode": "CB1 2HU"}}, "sen_status": "SEN Support", "fsm_eligible": false, "exclusions": 1, "behaviour_notes": "Verbal warning Oct 2024"}')
  AS t(pupil_id, first_name, last_name, gender, date_of_birth, school_urn, year_group, metadata_json)
)
SELECT * FROM base_pupils;

-- %%
-- Pupils snapshot: Spring 2025
-- Issues: SCHEMA DRIFT (different column names), more orphans, moved pupils, inconsistencies
-- Natural key duplicates have conflicting metadata fields
-- Each pupil has an address, and each parent contact has an address
CREATE OR REPLACE TABLE bronze.pupils_spring_2025 AS
SELECT * FROM VALUES
  -- Note: 'forename'/'surname' instead of 'first_name'/'last_name', 'dob' instead of 'date_of_birth', 'urn' instead of 'school_urn'
  ('P001', 'Alice',   'Johnson',   'Female',  '2012-03-15', 100001, 'Year 7',  '{"address": {"line1": "14 Maple Road", "city": "London", "postcode": "E1 6AN"}, "contact": {"parent_name": "Sarah Johnson", "phone": "07700900001", "email": "s.johnson@email.com", "address": {"line1": "14 Maple Road", "city": "London", "postcode": "E1 6AN"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 96.2}'),
  ('P002', 'Bob',     'Smith',     'Male',    '2011-07-22', 100001, 'Year 8',  '{"address": {"line1": "7 Cedar Close", "city": "London", "postcode": "N1 3PQ"}, "contact": {"parent_name": "David Smith", "phone": "07700900002", "email": "d.smith@email.com", "address": {"line1": "7 Cedar Close", "city": "London", "postcode": "N1 3PQ"}}, "sen_status": "SEN Support", "fsm_eligible": true, "attendance_pct": 88.5}'),
  ('P003', 'Carol',   'Williams',  'Female',  '2012-11-01', 100002, 'Year 7',  '{"address": {"line1": "23 Birch Lane", "city": "Manchester", "postcode": "M4 1HJ"}, "contact": {"parent_name": "Jane Williams", "phone": "07700900003", "email": "j.williams@email.com", "address": {"line1": "23 Birch Lane", "city": "Manchester", "postcode": "M4 1HJ"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 97.8}'),
  -- P004 moved from Birch College (now closed) to Willow Park — new Bristol address
  ('P004', 'Dan',     'Brown',     'Male',    '2010-09-30', 100005, 'Year 9',  '{"address": {"line1": "31 Park Avenue", "city": "Bristol", "postcode": "BS1 5AH"}, "contact": {"parent_name": "Mike Brown", "phone": "07700900004", "address": {"line1": "31 Park Avenue", "city": "Bristol", "postcode": "BS1 5AH"}}, "sen_status": "EHCP", "fsm_eligible": true, "attendance_pct": 72.1}'),
  ('P005', 'Eve',     'Taylor',    'Female',  '2013-01-18', 100004, 'Year 6',  '{"address": {"line1": "45 Willow Way", "city": "Leeds", "postcode": "LS1 4DY"}, "contact": {"parent_name": "Lisa Taylor", "phone": "07700900005", "email": "l.taylor@email.com", "address": {"line1": "45 Willow Way", "city": "Leeds", "postcode": "LS1 4DY"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 99.0}'),
  ('P006', 'Frank',   'Davies',    'Male',    '2011-05-25', 100005, 'Year 8',  '{"address": {"line1": "18 Hawthorn Street", "city": "Bristol", "postcode": "BS2 8NJ"}, "contact": {"parent_name": "Helen Davies", "phone": "07700900006", "address": {"line1": "18 Hawthorn Street", "city": "Bristol", "postcode": "BS2 8NJ"}}, "sen_status": "SEN Support", "fsm_eligible": false, "attendance_pct": 91.3}'),
  ('P007', 'Grace',   'Evans',     'Female',  '2012-08-12', 100006, 'Year 7',  '{"address": {"line1": "6 Rosemary Gardens", "city": "Sheffield", "postcode": "S1 2FP"}, "contact": {"parent_name": "Tom Evans", "phone": "07700900007", "email": "t.evans@email.com", "address": {"line1": "6 Rosemary Gardens", "city": "Sheffield", "postcode": "S1 2FP"}}, "sen_status": "None", "fsm_eligible": true, "attendance_pct": 94.6}'),
  ('P008', 'Harry',   'Wilson',    'Male',    '2010-12-03', 100007, 'Year 9',  '{"address": {"line1": "52 Lime Avenue", "city": "Liverpool", "postcode": "L3 9DA"}, "contact": {"parent_name": "Claire Wilson", "address": {"line1": "52 Lime Avenue", "city": "Liverpool", "postcode": "L3 9DA"}}, "sen_status": "EHCP", "fsm_eligible": true, "attendance_pct": 68.9}'),
  ('P009', 'Isla',    'Thomas',    'Female',  '2013-04-07', 100008, 'Year 6',  '{"address": {"line1": "3 Chestnut Terrace", "city": "London", "postcode": "SE1 7RG"}, "contact": {"parent_name": "Paul Thomas", "phone": "07700900009", "email": "p.thomas@email.com", "address": {"line1": "3 Chestnut Terrace", "city": "London", "postcode": "SE1 7RG"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 95.4}'),
  ('P010', 'Jack',    'Roberts',   'Male',    '2011-10-19', 100009, 'Year 8',  '{"address": {"line1": "28 Ash Grove", "city": "Nottingham", "postcode": "NG1 5LL"}, "contact": {"parent_name": "Karen Roberts", "phone": "07700900010", "address": {"line1": "28 Ash Grove", "city": "Nottingham", "postcode": "NG1 5LL"}}, "sen_status": "SEN Support", "fsm_eligible": true, "attendance_pct": 85.2}'),
  ('P011', 'Katie',   'Jones',     'Female',  '2012-06-28', 100010, 'Year 7',  '{"address": {"line1": "11 Ivy Crescent", "city": "Canterbury", "postcode": "CT1 2XB"}, "contact": {"parent_name": "Emma Jones", "phone": "07700900011", "address": {"line1": "11 Ivy Crescent", "city": "Canterbury", "postcode": "CT1 2XB"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 98.1}'),
  ('P012', 'Liam',    'Garcia',    'Male',    '2011-02-15', 100012, 'Year 8',  '{"address": {"line1": "16 Pine Close", "city": "Newcastle", "postcode": "NE1 4RT"}, "contact": {"parent_name": "Maria Garcia", "address": {"line1": "16 Pine Close", "city": "Newcastle", "postcode": "NE1 4RT"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 90.7}'),
  ('P013', 'Mia',     'Anderson',  'Female',  '2013-03-22', 100013, 'Year 6',  '{"address": {"line1": "39 Beech Road", "city": "Oxford", "postcode": "OX1 3SG"}, "contact": {"parent_name": "Chris Anderson", "phone": "07700900013", "email": "c.anderson@email.com", "address": {"line1": "39 Beech Road", "city": "Oxford", "postcode": "OX1 3SG"}}, "sen_status": "None", "fsm_eligible": true, "attendance_pct": 93.5}'),
  ('P014', 'Noah',    'Martinez',  'Male',    '2010-11-14', 100014, 'Year 9',  '{"address": {"line1": "22 Laurel Street", "city": "Cambridge", "postcode": "CB1 2HU"}, "contact": {"parent_name": "Ana Martinez", "phone": "07700900014", "address": {"line1": "22 Laurel Street", "city": "Cambridge", "postcode": "CB1 2HU"}}, "sen_status": "SEN Support", "fsm_eligible": false, "attendance_pct": 87.3}'),
  ('P015', 'Olivia',  'Lee',       'Female',  '2012-02-09', 100015, 'Year 7',  '{"address": {"line1": "8 Juniper Way", "city": "Bath", "postcode": "BA1 3NE"}, "contact": {"parent_name": "James Lee", "phone": "07700900015", "email": "j.lee@email.com", "address": {"line1": "8 Juniper Way", "city": "Bath", "postcode": "BA1 3NE"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 96.9}'),
  ('P016', 'Peter',   'Clark',     'Male',    '2011-08-17', 100016, 'Year 8',  '{"address": {"line1": "55 Rowan Drive", "city": "York", "postcode": "YO1 6BW"}, "contact": {"parent_name": "Susan Clark", "phone": "07700900016", "address": {"line1": "55 Rowan Drive", "city": "York", "postcode": "YO1 6BW"}}, "sen_status": "None", "fsm_eligible": true, "attendance_pct": 92.0}'),
  ('P017', 'Quinn',   'Lewis',     'Female',  '2013-07-03', 100017, 'Year 6',  '{"address": {"line1": "12 Holly Lane", "city": "Plymouth", "postcode": "PL1 4DX"}, "contact": {"parent_name": "Robert Lewis", "phone": "07700900017", "email": "r.lewis@email.com", "address": {"line1": "12 Holly Lane", "city": "Plymouth", "postcode": "PL1 4DX"}}, "sen_status": "EHCP", "fsm_eligible": true, "attendance_pct": 78.4}'),
  ('P018', 'Ryan',    'Walker',    'Male',    '2010-04-26', 100018, 'Year 9',  '{"address": {"line1": "34 Poplar Avenue", "city": "Coventry", "postcode": "CV1 5FG"}, "contact": {"parent_name": "Michelle Walker", "address": {"line1": "34 Poplar Avenue", "city": "Coventry", "postcode": "CV1 5FG"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 94.1}'),
  -- Orphaned: school 999999 still doesn''t exist
  ('P019', 'Sophie',  'Hall',      'Female',  '2012-09-11', 999999, 'Year 7',  '{"address": {"line1": "19 Alder Close", "city": "London", "postcode": "SW1 8QR"}, "contact": {"parent_name": "Mark Hall", "phone": "07700900019", "address": {"line1": "19 Alder Close", "city": "London", "postcode": "SW1 8QR"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 95.0}'),
  ('P020', 'Tom',     'Wright',    'Male',    '2011-03-08', 100001, 'Year 8',  '{"address": {"line1": "41 Sycamore Road", "city": "London", "postcode": "E2 0PL"}, "contact": {"parent_name": "Linda Wright", "address": {"line1": "41 Sycamore Road", "city": "London", "postcode": "E2 0PL"}}, "sen_status": "SEN Support", "fsm_eligible": true, "attendance_pct": 82.6}'),
  ('P021', 'Uma',     'Young',     'Female',  '2013-12-25', 100002, 'Year 6',  '{"address": {"line1": "5 Yew Tree Lane", "city": "Manchester", "postcode": "M3 4JK"}, "contact": {"parent_name": "Raj Young", "phone": "07700900021", "address": {"line1": "5 Yew Tree Lane", "city": "Manchester", "postcode": "M3 4JK"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 97.3}'),
  ('P022', 'Victor',  'King',      'Male',    '2011-06-14', 100005, 'Year 8',  '{"address": {"line1": "27 Hazel Court", "city": "Bristol", "postcode": "BS3 1RT"}, "contact": {"parent_name": "Janet King", "phone": "07700900022", "address": {"line1": "27 Hazel Court", "city": "Bristol", "postcode": "BS3 1RT"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 91.8}'),
  -- New pupil at new school
  ('P023', 'Wendy',   'Scott',     'Female',  '2012-10-05', 100019, 'Year 7',  '{"address": {"line1": "15 Walnut Drive", "city": "Reading", "postcode": "RG1 2MN"}, "contact": {"parent_name": "Brian Scott", "phone": "07700900023", "email": "b.scott@email.com", "address": {"line1": "15 Walnut Drive", "city": "Reading", "postcode": "RG1 2MN"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 96.5}'),
  -- Orphaned: references closed school 100003
  ('P024', 'Xander',  'Green',     'Male',    '2010-08-20', 100003, 'Year 9',  '{"address": {"line1": "48 Spruce Way", "city": "Birmingham", "postcode": "B12 8EH"}, "contact": {"parent_name": "Fiona Green", "address": {"line1": "48 Spruce Way", "city": "Birmingham", "postcode": "B12 8EH"}}, "sen_status": "SEN Support", "fsm_eligible": true, "attendance_pct": 74.2}'),
  -- Additional pupils for volume
  ('P027', 'Amber',   'Mitchell',  'Female',  '2012-05-14', 100002, 'Year 7',  '{"address": {"line1": "17 Primrose Lane", "city": "Manchester", "postcode": "M5 2DA"}, "contact": {"parent_name": "Laura Mitchell", "phone": "07700900027", "email": "l.mitchell@email.com", "address": {"line1": "17 Primrose Lane", "city": "Manchester", "postcode": "M5 2DA"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 97.5}'),
  ('P028', 'Ben',     'Cooper',    'Male',    '2011-01-30', 100006, 'Year 8',  '{"address": {"line1": "44 Bluebell Way", "city": "Sheffield", "postcode": "S3 7HN"}, "contact": {"parent_name": "Gary Cooper", "phone": "07700900028", "address": {"line1": "44 Bluebell Way", "city": "Sheffield", "postcode": "S3 7HN"}}, "sen_status": "SEN Support", "fsm_eligible": true, "attendance_pct": 84.3}'),
  ('P029', 'Chloe',   'Murphy',    'Female',  '2013-02-11', 100014, 'Year 6',  '{"address": {"line1": "10 Foxglove Road", "city": "Cambridge", "postcode": "CB2 1TP"}, "contact": {"parent_name": "Fiona Murphy", "phone": "07700900029", "email": "f.murphy@email.com", "address": {"line1": "10 Foxglove Road", "city": "Cambridge", "postcode": "CB2 1TP"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 95.6}'),
  -- Exact duplicate (carbon copy)
  ('P010', 'Jack',    'Roberts',   'Male',    '2011-10-19', 100009, 'Year 8',  '{"address": {"line1": "28 Ash Grove", "city": "Nottingham", "postcode": "NG1 5LL"}, "contact": {"parent_name": "Karen Roberts", "phone": "07700900010", "address": {"line1": "28 Ash Grove", "city": "Nottingham", "postcode": "NG1 5LL"}}, "sen_status": "SEN Support", "fsm_eligible": true, "attendance_pct": 85.2}'),
  -- Natural key duplicate: P003 — conflicting attendance_pct, extra allergy_info field
  ('P003', 'Carol',   'Williams',  'Female',  '2012-11-01', 100002, 'Year 7',  '{"address": {"line1": "23 Birch Lane", "city": "Manchester", "postcode": "M4 1HJ"}, "contact": {"parent_name": "Jane Williams", "phone": "07700900003", "email": "j.williams@email.com", "address": {"line1": "23 Birch Lane", "city": "Manchester", "postcode": "M4 1HJ"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 91.2, "allergy_info": "Nut allergy - EpiPen in school office"}'),
  -- Natural key duplicate: P007 — fsm_eligible flipped, extra dietary_requirements field
  ('P007', 'Grace',   'Evans',     'Female',  '2012-08-12', 100006, 'Year 7',  '{"address": {"line1": "6 Rosemary Gardens", "city": "Sheffield", "postcode": "S1 2FP"}, "contact": {"parent_name": "Tom Evans", "phone": "07700900007", "email": "t.evans@email.com", "address": {"line1": "6 Rosemary Gardens", "city": "Sheffield", "postcode": "S1 2FP"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 94.6, "dietary_requirements": "Vegetarian"}'),
  -- Natural key duplicate: P015 — SEN status changed, extra learning_support_plan field
  ('P015', 'Olivia',  'Lee',       'Female',  '2012-02-09', 100015, 'Year 7',  '{"address": {"line1": "8 Juniper Way", "city": "Bath", "postcode": "BA1 3NE"}, "contact": {"parent_name": "James Lee", "phone": "07700900015", "email": "j.lee@email.com", "address": {"line1": "8 Juniper Way", "city": "Bath", "postcode": "BA1 3NE"}}, "sen_status": "SEN Support", "fsm_eligible": false, "attendance_pct": 96.9, "learning_support_plan": "Small group intervention - literacy"}'),
  -- Natural key duplicate: P017 — different parent phone, extra secondary_contact
  ('P017', 'Quinn',   'Lewis',     'Female',  '2013-07-03', 100017, 'Year 6',  '{"address": {"line1": "12 Holly Lane", "city": "Plymouth", "postcode": "PL1 4DX"}, "contact": {"parent_name": "Robert Lewis", "phone": "07700900088", "address": {"line1": "12 Holly Lane", "city": "Plymouth", "postcode": "PL1 4DX"}}, "sen_status": "EHCP", "fsm_eligible": true, "attendance_pct": 78.4, "secondary_contact": {"name": "Diana Lewis", "phone": "07700900089", "relationship": "Mother"}}')
AS t(pupil_id, forename, surname, sex, dob, urn, year_group, metadata_json);

-- %%
-- Pupils snapshot: Summer 2025
-- Issues: NEW COLUMN 'ethnicity' added (mirrors summer schools adding 'region'), inconsistent ethnicity values,
-- NULL/empty ethnicity, new pupils at new schools (100020, 100021), orphaned refs, duplicates
-- Natural key duplicates have conflicting metadata fields
-- Each pupil has an address, and each parent contact has an address
-- Retains spring column names (forename, surname, sex, dob, urn)
CREATE OR REPLACE TABLE bronze.pupils_summer_2025 AS
SELECT * FROM VALUES
  ('P001', 'Alice',   'Johnson',   'Female',  '2012-03-15', 100001, 'Year 7',  'White British',    '{"address": {"line1": "14 Maple Road", "city": "London", "postcode": "E1 6AN"}, "contact": {"parent_name": "Sarah Johnson", "phone": "07700900001", "email": "s.johnson@email.com", "address": {"line1": "14 Maple Road", "city": "London", "postcode": "E1 6AN"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 95.8}'),
  ('P002', 'Bob',     'Smith',     'Male',    '2011-07-22', 100001, 'Year 8',  'White British',    '{"address": {"line1": "7 Cedar Close", "city": "London", "postcode": "N1 3PQ"}, "contact": {"parent_name": "David Smith", "phone": "07700900002", "email": "d.smith@email.com", "address": {"line1": "7 Cedar Close", "city": "London", "postcode": "N1 3PQ"}}, "sen_status": "SEN Support", "fsm_eligible": true, "attendance_pct": 86.1}'),
  ('P003', 'Carol',   'Williams',  'Female',  '2012-11-01', 100002, 'Year 7',  'White British',    '{"address": {"line1": "23 Birch Lane", "city": "Manchester", "postcode": "M4 1HJ"}, "contact": {"parent_name": "Jane Williams", "phone": "07700900003", "email": "j.williams@email.com", "address": {"line1": "23 Birch Lane", "city": "Manchester", "postcode": "M4 1HJ"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 97.2}'),
  ('P004', 'Dan',     'Brown',     'Male',    '2010-09-30', 100005, 'Year 9',  'Mixed',            '{"address": {"line1": "31 Park Avenue", "city": "Bristol", "postcode": "BS1 5AH"}, "contact": {"parent_name": "Mike Brown", "phone": "07700900004", "address": {"line1": "31 Park Avenue", "city": "Bristol", "postcode": "BS1 5AH"}}, "sen_status": "EHCP", "fsm_eligible": true, "attendance_pct": 70.5}'),
  ('P005', 'Eve',     'Taylor',    'Female',  '2013-01-18', 100004, 'Year 6',  'White British',    '{"address": {"line1": "45 Willow Way", "city": "Leeds", "postcode": "LS1 4DY"}, "contact": {"parent_name": "Lisa Taylor", "phone": "07700900005", "email": "l.taylor@email.com", "address": {"line1": "45 Willow Way", "city": "Leeds", "postcode": "LS1 4DY"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 98.7}'),
  ('P006', 'Frank',   'Davies',    'Male',    '2011-05-25', 100005, 'Year 8',  'White British',    '{"address": {"line1": "18 Hawthorn Street", "city": "Bristol", "postcode": "BS2 8NJ"}, "contact": {"parent_name": "Helen Davies", "phone": "07700900006", "address": {"line1": "18 Hawthorn Street", "city": "Bristol", "postcode": "BS2 8NJ"}}, "sen_status": "SEN Support", "fsm_eligible": false, "attendance_pct": 90.9}'),
  ('P007', 'Grace',   'Evans',     'Female',  '2012-08-12', 100006, 'Year 7',  'asian',            '{"address": {"line1": "6 Rosemary Gardens", "city": "Sheffield", "postcode": "S1 2FP"}, "contact": {"parent_name": "Tom Evans", "phone": "07700900007", "email": "t.evans@email.com", "address": {"line1": "6 Rosemary Gardens", "city": "Sheffield", "postcode": "S1 2FP"}}, "sen_status": "None", "fsm_eligible": true, "attendance_pct": 93.8}'),
  ('P008', 'Harry',   'Wilson',    'Male',    '2010-12-03', 100007, 'Year 9',  'BLACK AFRICAN',    '{"address": {"line1": "52 Lime Avenue", "city": "Liverpool", "postcode": "L3 9DA"}, "contact": {"parent_name": "Claire Wilson", "address": {"line1": "52 Lime Avenue", "city": "Liverpool", "postcode": "L3 9DA"}}, "sen_status": "EHCP", "fsm_eligible": true, "attendance_pct": 66.4}'),
  ('P009', 'Isla',    'Thomas',    'Female',  '2013-04-07', 100008, 'Year 6',  'White British',    '{"address": {"line1": "3 Chestnut Terrace", "city": "London", "postcode": "SE1 7RG"}, "contact": {"parent_name": "Paul Thomas", "phone": "07700900009", "email": "p.thomas@email.com", "address": {"line1": "3 Chestnut Terrace", "city": "London", "postcode": "SE1 7RG"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 94.9}'),
  ('P010', 'Jack',    'Roberts',   'Male',    '2011-10-19', 100009, 'Year 8',  'White British',    '{"address": {"line1": "28 Ash Grove", "city": "Nottingham", "postcode": "NG1 5LL"}, "contact": {"parent_name": "Karen Roberts", "phone": "07700900010", "address": {"line1": "28 Ash Grove", "city": "Nottingham", "postcode": "NG1 5LL"}}, "sen_status": "SEN Support", "fsm_eligible": true, "attendance_pct": 84.0}'),
  ('P011', 'Katie',   'Jones',     'Female',  '2012-06-28', 100010, 'Year 7',  'Mixed White Asian','{"address": {"line1": "11 Ivy Crescent", "city": "Canterbury", "postcode": "CT1 2XB"}, "contact": {"parent_name": "Emma Jones", "phone": "07700900011", "address": {"line1": "11 Ivy Crescent", "city": "Canterbury", "postcode": "CT1 2XB"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 97.5}'),
  ('P012', 'Liam',    'Garcia',    'Male',    '2011-02-15', 100012, 'Year 8',  'Other',            '{"address": {"line1": "16 Pine Close", "city": "Newcastle", "postcode": "NE1 4RT"}, "contact": {"parent_name": "Maria Garcia", "address": {"line1": "16 Pine Close", "city": "Newcastle", "postcode": "NE1 4RT"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 89.4}'),
  ('P013', 'Mia',     'Anderson',  'Female',  '2013-03-22', 100013, 'Year 6',  'White British',    '{"address": {"line1": "39 Beech Road", "city": "Oxford", "postcode": "OX1 3SG"}, "contact": {"parent_name": "Chris Anderson", "phone": "07700900013", "email": "c.anderson@email.com", "address": {"line1": "39 Beech Road", "city": "Oxford", "postcode": "OX1 3SG"}}, "sen_status": "None", "fsm_eligible": true, "attendance_pct": 92.1}'),
  ('P014', 'Noah',    'Martinez',  'Male',    '2010-11-14', 100014, 'Year 9',  'Other White',      '{"address": {"line1": "22 Laurel Street", "city": "Cambridge", "postcode": "CB1 2HU"}, "contact": {"parent_name": "Ana Martinez", "phone": "07700900014", "address": {"line1": "22 Laurel Street", "city": "Cambridge", "postcode": "CB1 2HU"}}, "sen_status": "SEN Support", "fsm_eligible": false, "attendance_pct": 86.0}'),
  ('P015', 'Olivia',  'Lee',       'Female',  '2012-02-09', 100015, 'Year 7',  'asian british',    '{"address": {"line1": "8 Juniper Way", "city": "Bath", "postcode": "BA1 3NE"}, "contact": {"parent_name": "James Lee", "phone": "07700900015", "email": "j.lee@email.com", "address": {"line1": "8 Juniper Way", "city": "Bath", "postcode": "BA1 3NE"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 96.3}'),
  ('P016', 'Peter',   'Clark',     'Male',    '2011-08-17', 100016, 'Year 8',  'White British',    '{"address": {"line1": "55 Rowan Drive", "city": "York", "postcode": "YO1 6BW"}, "contact": {"parent_name": "Susan Clark", "phone": "07700900016", "address": {"line1": "55 Rowan Drive", "city": "York", "postcode": "YO1 6BW"}}, "sen_status": "None", "fsm_eligible": true, "attendance_pct": 91.5}'),
  ('P017', 'Quinn',   'Lewis',     'Female',  '2013-07-03', 100017, 'Year 6',  'White British',    '{"address": {"line1": "12 Holly Lane", "city": "Plymouth", "postcode": "PL1 4DX"}, "contact": {"parent_name": "Robert Lewis", "phone": "07700900017", "email": "r.lewis@email.com", "address": {"line1": "12 Holly Lane", "city": "Plymouth", "postcode": "PL1 4DX"}}, "sen_status": "EHCP", "fsm_eligible": true, "attendance_pct": 76.8}'),
  ('P018', 'Ryan',    'Walker',    'Male',    '2010-04-26', 100018, 'Year 9',  '',                 '{"address": {"line1": "34 Poplar Avenue", "city": "Coventry", "postcode": "CV1 5FG"}, "contact": {"parent_name": "Michelle Walker", "address": {"line1": "34 Poplar Avenue", "city": "Coventry", "postcode": "CV1 5FG"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 93.7}'),
  -- Orphaned: school 999999 still doesn''t exist
  ('P019', 'Sophie',  'Hall',      'Female',  '2012-09-11', 999999, 'Year 7',  'White British',    '{"address": {"line1": "19 Alder Close", "city": "London", "postcode": "SW1 8QR"}, "contact": {"parent_name": "Mark Hall", "phone": "07700900019", "address": {"line1": "19 Alder Close", "city": "London", "postcode": "SW1 8QR"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 94.5}'),
  ('P020', 'Tom',     'Wright',    'Male',    '2011-03-08', 100001, 'Year 8',  NULL,               '{"address": {"line1": "41 Sycamore Road", "city": "London", "postcode": "E2 0PL"}, "contact": {"parent_name": "Linda Wright", "address": {"line1": "41 Sycamore Road", "city": "London", "postcode": "E2 0PL"}}, "sen_status": "SEN Support", "fsm_eligible": true, "attendance_pct": 81.3}'),
  ('P021', 'Uma',     'Young',     'Female',  '2013-12-25', 100002, 'Year 6',  'N/A',              '{"address": {"line1": "5 Yew Tree Lane", "city": "Manchester", "postcode": "M3 4JK"}, "contact": {"parent_name": "Raj Young", "phone": "07700900021", "address": {"line1": "5 Yew Tree Lane", "city": "Manchester", "postcode": "M3 4JK"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 96.8}'),
  ('P022', 'Victor',  'King',      'Male',    '2011-06-14', 100005, 'Year 8',  'White British',    '{"address": {"line1": "27 Hazel Court", "city": "Bristol", "postcode": "BS3 1RT"}, "contact": {"parent_name": "Janet King", "phone": "07700900022", "address": {"line1": "27 Hazel Court", "city": "Bristol", "postcode": "BS3 1RT"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 90.2}'),
  ('P023', 'Wendy',   'Scott',     'Female',  '2012-10-05', 100019, 'Year 7',  'White British',    '{"address": {"line1": "15 Walnut Drive", "city": "Reading", "postcode": "RG1 2MN"}, "contact": {"parent_name": "Brian Scott", "phone": "07700900023", "email": "b.scott@email.com", "address": {"line1": "15 Walnut Drive", "city": "Reading", "postcode": "RG1 2MN"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 95.9}'),
  -- Orphaned: references closed school 100003
  ('P024', 'Xander',  'Green',     'Male',    '2010-08-20', 100003, 'Year 9',  'White British',    '{"address": {"line1": "48 Spruce Way", "city": "Birmingham", "postcode": "B12 8EH"}, "contact": {"parent_name": "Fiona Green", "address": {"line1": "48 Spruce Way", "city": "Birmingham", "postcode": "B12 8EH"}}, "sen_status": "SEN Support", "fsm_eligible": true, "attendance_pct": 73.1}'),
  -- New pupils at new schools
  ('P025', 'Yara',    'Patel',     'Female',  '2013-05-11', 100020, 'Year 6',  'Asian Indian',     '{"address": {"line1": "32 Fern Close", "city": "Brighton", "postcode": "BN1 4KJ"}, "contact": {"parent_name": "Priya Patel", "phone": "07700900025", "email": "p.patel@email.com", "address": {"line1": "32 Fern Close", "city": "Brighton", "postcode": "BN1 4KJ"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 97.1}'),
  ('P026', 'Zach',    'O''Brien',  'Male',    '2011-09-28', 100021, 'Year 8',  'white irish',      '{"address": {"line1": "21 Heather Road", "city": "Exeter", "postcode": "EX1 3LP"}, "contact": {"parent_name": "Siobhan O''Brien", "phone": "07700900026", "address": {"line1": "21 Heather Road", "city": "Exeter", "postcode": "EX1 3LP"}}, "sen_status": "SEN Support", "fsm_eligible": true, "attendance_pct": 83.6}'),
  -- Additional pupils for volume
  ('P027', 'Amber',   'Mitchell',  'Female',  '2012-05-14', 100002, 'Year 7',  'White British',    '{"address": {"line1": "17 Primrose Lane", "city": "Manchester", "postcode": "M5 2DA"}, "contact": {"parent_name": "Laura Mitchell", "phone": "07700900027", "email": "l.mitchell@email.com", "address": {"line1": "17 Primrose Lane", "city": "Manchester", "postcode": "M5 2DA"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 96.8}'),
  ('P028', 'Ben',     'Cooper',    'Male',    '2011-01-30', 100006, 'Year 8',  'White British',    '{"address": {"line1": "44 Bluebell Way", "city": "Sheffield", "postcode": "S3 7HN"}, "contact": {"parent_name": "Gary Cooper", "phone": "07700900028", "address": {"line1": "44 Bluebell Way", "city": "Sheffield", "postcode": "S3 7HN"}}, "sen_status": "SEN Support", "fsm_eligible": true, "attendance_pct": 83.0}'),
  ('P029', 'Chloe',   'Murphy',    'Female',  '2013-02-11', 100014, 'Year 6',  'White British',    '{"address": {"line1": "10 Foxglove Road", "city": "Cambridge", "postcode": "CB2 1TP"}, "contact": {"parent_name": "Fiona Murphy", "phone": "07700900029", "email": "f.murphy@email.com", "address": {"line1": "10 Foxglove Road", "city": "Cambridge", "postcode": "CB2 1TP"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 94.9}'),
  ('P030', 'Dylan',   'Reed',      'Male',    '2012-07-19', 100020, 'Year 7',  'Mixed White Black','{"address": {"line1": "36 Lavender Close", "city": "Brighton", "postcode": "BN2 3SW"}, "contact": {"parent_name": "Angela Reed", "phone": "07700900030", "address": {"line1": "36 Lavender Close", "city": "Brighton", "postcode": "BN2 3SW"}}, "sen_status": "None", "fsm_eligible": true, "attendance_pct": 89.7}'),
  -- Exact duplicate (carbon copy)
  ('P007', 'Grace',   'Evans',     'Female',  '2012-08-12', 100006, 'Year 7',  'asian',            '{"address": {"line1": "6 Rosemary Gardens", "city": "Sheffield", "postcode": "S1 2FP"}, "contact": {"parent_name": "Tom Evans", "phone": "07700900007", "email": "t.evans@email.com", "address": {"line1": "6 Rosemary Gardens", "city": "Sheffield", "postcode": "S1 2FP"}}, "sen_status": "None", "fsm_eligible": true, "attendance_pct": 93.8}'),
  -- Natural key duplicate: P002 — updated email, extra behaviour_log field
  ('P002', 'Bob',     'Smith',     'Male',    '2011-07-22', 100001, 'Year 8',  'White British',    '{"address": {"line1": "7 Cedar Close", "city": "London", "postcode": "N1 3PQ"}, "contact": {"parent_name": "David Smith", "phone": "07700900002", "email": "bob.smith@newemail.com", "address": {"line1": "7 Cedar Close", "city": "London", "postcode": "N1 3PQ"}}, "sen_status": "SEN Support", "fsm_eligible": true, "attendance_pct": 86.1, "behaviour_log": [{"date": "2025-05-10", "type": "merit", "notes": "Excellent group work"}]}'),
  -- Natural key duplicate: P009 — fsm_eligible flipped, extra medical_notes field
  ('P009', 'Isla',    'Thomas',    'Female',  '2013-04-07', 100008, 'Year 6',  'White British',    '{"address": {"line1": "3 Chestnut Terrace", "city": "London", "postcode": "SE1 7RG"}, "contact": {"parent_name": "Paul Thomas", "phone": "07700900009", "email": "p.thomas@email.com", "address": {"line1": "3 Chestnut Terrace", "city": "London", "postcode": "SE1 7RG"}}, "sen_status": "None", "fsm_eligible": true, "attendance_pct": 94.9, "medical_notes": "Requires glasses for board work"}'),
  -- Natural key duplicate: P013 — conflicting attendance_pct, extra assessment_notes
  ('P013', 'Mia',     'Anderson',  'Female',  '2013-03-22', 100013, 'Year 6',  'White British',    '{"address": {"line1": "39 Beech Road", "city": "Oxford", "postcode": "OX1 3SG"}, "contact": {"parent_name": "Chris Anderson", "phone": "07700900013", "email": "c.anderson@email.com", "address": {"line1": "39 Beech Road", "city": "Oxford", "postcode": "OX1 3SG"}}, "sen_status": "None", "fsm_eligible": true, "attendance_pct": 88.4, "assessment_notes": "Below expected standard in maths - intervention recommended"}'),
  -- Natural key duplicate: P020 — SEN status conflict, fsm_eligible conflict
  ('P020', 'Tom',     'Wright',    'Male',    '2011-03-08', 100001, 'Year 8',  NULL,               '{"address": {"line1": "41 Sycamore Road", "city": "London", "postcode": "E2 0PL"}, "contact": {"parent_name": "Linda Wright", "phone": "07700900020", "address": {"line1": "41 Sycamore Road", "city": "London", "postcode": "E2 0PL"}}, "sen_status": "None", "fsm_eligible": false, "attendance_pct": 81.3}')
AS t(pupil_id, forename, surname, sex, dob, urn, year_group, ethnicity, metadata_json);

-- %%
-- Pupils snapshot: Autumn 2025
-- Issues: COLUMN REMOVED — year_group is no longer in the extract (mirrors autumn schools removing phase)
-- Schema drifts back to autumn-style column names (first_name, last_name, gender, date_of_birth, school_urn)
-- P024 (Xander Green) removed after Birch College closure, P019 still orphaned
-- Natural key duplicates have conflicting metadata fields
-- Each pupil has an address, and each parent contact has an address
CREATE OR REPLACE TABLE bronze.pupils_autumn_2025 AS
SELECT * FROM VALUES
  ('P001', 'Alice',   'Johnson',   'F', '2012-03-15', 100001, '{"address": {"line1": "14 Maple Road", "city": "London", "postcode": "E1 6AN"}, "contact": {"parent_name": "Sarah Johnson", "phone": "07700900001", "email": "s.johnson@email.com", "address": {"line1": "14 Maple Road", "city": "London", "postcode": "E1 6AN"}}, "sen_status": "None", "fsm_eligible": false}'),
  ('P002', 'Bob',     'Smith',     'M', '2011-07-22', 100001, '{"address": {"line1": "7 Cedar Close", "city": "London", "postcode": "N1 3PQ"}, "contact": {"parent_name": "David Smith", "phone": "07700900002", "email": "d.smith@email.com", "address": {"line1": "7 Cedar Close", "city": "London", "postcode": "N1 3PQ"}}, "sen_status": "SEN Support", "fsm_eligible": true}'),
  ('P003', 'Carol',   'Williams',  'F', '2012-11-01', 100002, '{"address": {"line1": "23 Birch Lane", "city": "Manchester", "postcode": "M4 1HJ"}, "contact": {"parent_name": "Jane Williams", "phone": "07700900003", "email": "j.williams@email.com", "address": {"line1": "23 Birch Lane", "city": "Manchester", "postcode": "M4 1HJ"}}, "sen_status": "None", "fsm_eligible": false}'),
  ('P004', 'Dan',     'Brown',     'M', '2010-09-30', 100005, '{"address": {"line1": "31 Park Avenue", "city": "Bristol", "postcode": "BS1 5AH"}, "contact": {"parent_name": "Mike Brown", "phone": "07700900004", "address": {"line1": "31 Park Avenue", "city": "Bristol", "postcode": "BS1 5AH"}}, "sen_status": "EHCP", "fsm_eligible": true}'),
  ('P005', 'Eve',     'Taylor',    'F', '2013-01-18', 100004, '{"address": {"line1": "45 Willow Way", "city": "Leeds", "postcode": "LS1 4DY"}, "contact": {"parent_name": "Lisa Taylor", "phone": "07700900005", "email": "l.taylor@email.com", "address": {"line1": "45 Willow Way", "city": "Leeds", "postcode": "LS1 4DY"}}, "sen_status": "None", "fsm_eligible": false}'),
  ('P006', 'Frank',   'Davies',    'M', '2011-05-25', 100005, '{"address": {"line1": "18 Hawthorn Street", "city": "Bristol", "postcode": "BS2 8NJ"}, "contact": {"parent_name": "Helen Davies", "phone": "07700900006", "address": {"line1": "18 Hawthorn Street", "city": "Bristol", "postcode": "BS2 8NJ"}}, "sen_status": "SEN Support", "fsm_eligible": false}'),
  ('P007', 'Grace',   'Evans',     'F', '2012-08-12', 100006, '{"address": {"line1": "6 Rosemary Gardens", "city": "Sheffield", "postcode": "S1 2FP"}, "contact": {"parent_name": "Tom Evans", "phone": "07700900007", "email": "t.evans@email.com", "address": {"line1": "6 Rosemary Gardens", "city": "Sheffield", "postcode": "S1 2FP"}}, "sen_status": "None", "fsm_eligible": true}'),
  ('P008', 'Harry',   'Wilson',    'M', '2010-12-03', 100007, '{"address": {"line1": "52 Lime Avenue", "city": "Liverpool", "postcode": "L3 9DA"}, "contact": {"parent_name": "Claire Wilson", "address": {"line1": "52 Lime Avenue", "city": "Liverpool", "postcode": "L3 9DA"}}, "sen_status": "EHCP", "fsm_eligible": true}'),
  ('P009', 'Isla',    'Thomas',    'F', '2013-04-07', 100008, '{"address": {"line1": "3 Chestnut Terrace", "city": "London", "postcode": "SE1 7RG"}, "contact": {"parent_name": "Paul Thomas", "phone": "07700900009", "email": "p.thomas@email.com", "address": {"line1": "3 Chestnut Terrace", "city": "London", "postcode": "SE1 7RG"}}, "sen_status": "None", "fsm_eligible": false}'),
  ('P010', 'Jack',    'Roberts',   'M', '2011-10-19', 100009, '{"address": {"line1": "28 Ash Grove", "city": "Nottingham", "postcode": "NG1 5LL"}, "contact": {"parent_name": "Karen Roberts", "phone": "07700900010", "address": {"line1": "28 Ash Grove", "city": "Nottingham", "postcode": "NG1 5LL"}}, "sen_status": "SEN Support", "fsm_eligible": true}'),
  -- Inconsistent casing
  ('P011', 'katie',   'JONES',     'F', '2012-06-28', 100010, '{"address": {"line1": "11 Ivy Crescent", "city": "Canterbury", "postcode": "CT1 2XB"}, "contact": {"parent_name": "Emma Jones", "phone": "07700900011", "address": {"line1": "11 Ivy Crescent", "city": "Canterbury", "postcode": "CT1 2XB"}}, "sen_status": "None", "fsm_eligible": false}'),
  ('P012', 'LIAM',    'garcia',    'M', '2011-02-15', 100012, '{"address": {"line1": "16 Pine Close", "city": "Newcastle", "postcode": "NE1 4RT"}, "contact": {"parent_name": "Maria Garcia", "address": {"line1": "16 Pine Close", "city": "Newcastle", "postcode": "NE1 4RT"}}, "sen_status": "none", "fsm_eligible": false}'),
  ('P013', 'Mia',     'Anderson',  'F', '2013-03-22', 100013, '{"address": {"line1": "39 Beech Road", "city": "Oxford", "postcode": "OX1 3SG"}, "contact": {"parent_name": "Chris Anderson", "phone": "07700900013", "email": "c.anderson@email.com", "address": {"line1": "39 Beech Road", "city": "Oxford", "postcode": "OX1 3SG"}}, "sen_status": "None", "fsm_eligible": true}'),
  ('P014', 'Noah',    'Martinez',  'M', '2010-11-14', 100014, '{"address": {"line1": "22 Laurel Street", "city": "Cambridge", "postcode": "CB1 2HU"}, "contact": {"parent_name": "Ana Martinez", "phone": "07700900014", "address": {"line1": "22 Laurel Street", "city": "Cambridge", "postcode": "CB1 2HU"}}, "sen_status": "SEN Support", "fsm_eligible": false}'),
  ('P015', 'Olivia',  'Lee',       'F', '2012-02-09', 100015, '{"address": {"line1": "8 Juniper Way", "city": "Bath", "postcode": "BA1 3NE"}, "contact": {"parent_name": "James Lee", "phone": "07700900015", "email": "j.lee@email.com", "address": {"line1": "8 Juniper Way", "city": "Bath", "postcode": "BA1 3NE"}}, "sen_status": "None", "fsm_eligible": false}'),
  ('P016', 'Peter',   'Clark',     'M', '2011-08-17', 100016, '{"address": {"line1": "55 Rowan Drive", "city": "York", "postcode": "YO1 6BW"}, "contact": {"parent_name": "Susan Clark", "phone": "07700900016", "address": {"line1": "55 Rowan Drive", "city": "York", "postcode": "YO1 6BW"}}, "sen_status": "None", "fsm_eligible": true}'),
  ('P017', 'Quinn',   'Lewis',     'F', '2013-07-03', 100017, '{"address": {"line1": "12 Holly Lane", "city": "Plymouth", "postcode": "PL1 4DX"}, "contact": {"parent_name": "Robert Lewis", "phone": "07700900017", "email": "r.lewis@email.com", "address": {"line1": "12 Holly Lane", "city": "Plymouth", "postcode": "PL1 4DX"}}, "sen_status": "EHCP", "fsm_eligible": true}'),
  ('P018', 'Ryan',    'Walker',    'M', '2010-04-26', 100018, '{"address": {"line1": "34 Poplar Avenue", "city": "Coventry", "postcode": "CV1 5FG"}, "contact": {"parent_name": "Michelle Walker", "address": {"line1": "34 Poplar Avenue", "city": "Coventry", "postcode": "CV1 5FG"}}, "sen_status": "None", "fsm_eligible": false}'),
  -- Orphaned: school 999999 still doesn''t exist
  ('P019', 'Sophie',  'Hall',      'F', '2012-09-11', 999999, '{"address": {"line1": "19 Alder Close", "city": "London", "postcode": "SW1 8QR"}, "contact": {"parent_name": "Mark Hall", "phone": "07700900019", "address": {"line1": "19 Alder Close", "city": "London", "postcode": "SW1 8QR"}}, "sen_status": "None", "fsm_eligible": false}'),
  ('P020', 'Tom',     'Wright',    'M', '2011-03-08', 100001, '{"address": {"line1": "41 Sycamore Road", "city": "London", "postcode": "E2 0PL"}, "contact": {"parent_name": "Linda Wright", "address": {"line1": "41 Sycamore Road", "city": "London", "postcode": "E2 0PL"}}, "sen_status": "SEN Support", "fsm_eligible": true}'),
  ('P021', 'Uma',     'Young',     'F', '2013-12-25', 100002, '{"address": {"line1": "5 Yew Tree Lane", "city": "Manchester", "postcode": "M3 4JK"}, "contact": {"parent_name": "Raj Young", "phone": "07700900021", "address": {"line1": "5 Yew Tree Lane", "city": "Manchester", "postcode": "M3 4JK"}}, "sen_status": "None", "fsm_eligible": false}'),
  ('P022', 'Victor',  'King',      'M', '2011-06-14', 100005, '{"address": {"line1": "27 Hazel Court", "city": "Bristol", "postcode": "BS3 1RT"}, "contact": {"parent_name": "Janet King", "phone": "07700900022", "address": {"line1": "27 Hazel Court", "city": "Bristol", "postcode": "BS3 1RT"}}, "sen_status": "None", "fsm_eligible": false}'),
  ('P023', 'Wendy',   'Scott',     'F', '2012-10-05', 100019, '{"address": {"line1": "15 Walnut Drive", "city": "Reading", "postcode": "RG1 2MN"}, "contact": {"parent_name": "Brian Scott", "phone": "07700900023", "email": "b.scott@email.com", "address": {"line1": "15 Walnut Drive", "city": "Reading", "postcode": "RG1 2MN"}}, "sen_status": "None", "fsm_eligible": false}'),
  ('P025', 'Yara',    'Patel',     'F', '2013-05-11', 100020, '{"address": {"line1": "32 Fern Close", "city": "Brighton", "postcode": "BN1 4KJ"}, "contact": {"parent_name": "Priya Patel", "phone": "07700900025", "email": "p.patel@email.com", "address": {"line1": "32 Fern Close", "city": "Brighton", "postcode": "BN1 4KJ"}}, "sen_status": "None", "fsm_eligible": false}'),
  ('P026', 'Zach',    'O''Brien',  'M', '2011-09-28', 100021, '{"address": {"line1": "21 Heather Road", "city": "Exeter", "postcode": "EX1 3LP"}, "contact": {"parent_name": "Siobhan O''Brien", "phone": "07700900026", "address": {"line1": "21 Heather Road", "city": "Exeter", "postcode": "EX1 3LP"}}, "sen_status": "SEN Support", "fsm_eligible": true}'),
  -- Additional pupils for volume
  ('P027', 'Amber',   'Mitchell',  'F', '2012-05-14', 100002, '{"address": {"line1": "17 Primrose Lane", "city": "Manchester", "postcode": "M5 2DA"}, "contact": {"parent_name": "Laura Mitchell", "phone": "07700900027", "email": "l.mitchell@email.com", "address": {"line1": "17 Primrose Lane", "city": "Manchester", "postcode": "M5 2DA"}}, "sen_status": "None", "fsm_eligible": false}'),
  ('P028', 'Ben',     'Cooper',    'M', '2011-01-30', 100006, '{"address": {"line1": "44 Bluebell Way", "city": "Sheffield", "postcode": "S3 7HN"}, "contact": {"parent_name": "Gary Cooper", "phone": "07700900028", "address": {"line1": "44 Bluebell Way", "city": "Sheffield", "postcode": "S3 7HN"}}, "sen_status": "SEN Support", "fsm_eligible": true}'),
  ('P029', 'Chloe',   'Murphy',    'F', '2013-02-11', 100014, '{"address": {"line1": "10 Foxglove Road", "city": "Cambridge", "postcode": "CB2 1TP"}, "contact": {"parent_name": "Fiona Murphy", "phone": "07700900029", "email": "f.murphy@email.com", "address": {"line1": "10 Foxglove Road", "city": "Cambridge", "postcode": "CB2 1TP"}}, "sen_status": "None", "fsm_eligible": false}'),
  ('P030', 'Dylan',   'Reed',      'M', '2012-07-19', 100020, '{"address": {"line1": "36 Lavender Close", "city": "Brighton", "postcode": "BN2 3SW"}, "contact": {"parent_name": "Angela Reed", "phone": "07700900030", "address": {"line1": "36 Lavender Close", "city": "Brighton", "postcode": "BN2 3SW"}}, "sen_status": "None", "fsm_eligible": true}'),
  -- Exact duplicate (carbon copy)
  ('P001', 'Alice',   'Johnson',   'F', '2012-03-15', 100001, '{"address": {"line1": "14 Maple Road", "city": "London", "postcode": "E1 6AN"}, "contact": {"parent_name": "Sarah Johnson", "phone": "07700900001", "email": "s.johnson@email.com", "address": {"line1": "14 Maple Road", "city": "London", "postcode": "E1 6AN"}}, "sen_status": "None", "fsm_eligible": false}'),
  -- Natural key duplicate: P006 — fsm_eligible flipped, extra behaviour_notes field
  ('P006', 'Frank',   'Davies',    'M', '2011-05-25', 100005, '{"address": {"line1": "18 Hawthorn Street", "city": "Bristol", "postcode": "BS2 8NJ"}, "contact": {"parent_name": "Helen Davies", "phone": "07700900006", "address": {"line1": "18 Hawthorn Street", "city": "Bristol", "postcode": "BS2 8NJ"}}, "sen_status": "SEN Support", "fsm_eligible": true, "behaviour_notes": "Consistent effort in class, peer mentor role assigned"}'),
  -- Natural key duplicate: P010 — SEN status changed, different phone number
  ('P010', 'Jack',    'Roberts',   'M', '2011-10-19', 100009, '{"address": {"line1": "28 Ash Grove", "city": "Nottingham", "postcode": "NG1 5LL"}, "contact": {"parent_name": "Karen Roberts", "phone": "07700900077", "address": {"line1": "28 Ash Grove", "city": "Nottingham", "postcode": "NG1 5LL"}}, "sen_status": "None", "fsm_eligible": true, "sen_review_notes": "SEN Support discontinued Sep 2025 - meeting expected standard"}'),
  -- Natural key duplicate: P016 — different parent name, extra secondary_contact
  ('P016', 'Peter',   'Clark',     'M', '2011-08-17', 100016, '{"address": {"line1": "55 Rowan Drive", "city": "York", "postcode": "YO1 6BW"}, "contact": {"parent_name": "Richard Clark", "phone": "07700900055", "address": {"line1": "55 Rowan Drive", "city": "York", "postcode": "YO1 6BW"}}, "sen_status": "None", "fsm_eligible": true, "secondary_contact": {"name": "Susan Clark", "phone": "07700900016", "relationship": "Mother"}}'),
  -- Natural key duplicate: P022 — SEN status changed, extra learning_support field
  ('P022', 'Victor',  'King',      'M', '2011-06-14', 100005, '{"address": {"line1": "27 Hazel Court", "city": "Bristol", "postcode": "BS3 1RT"}, "contact": {"parent_name": "Janet King", "phone": "07700900022", "address": {"line1": "27 Hazel Court", "city": "Bristol", "postcode": "BS3 1RT"}}, "sen_status": "SEN Support", "fsm_eligible": false, "learning_support": "Small group numeracy intervention"}')
AS t(pupil_id, first_name, last_name, gender, date_of_birth, school_urn, metadata_json);

-- %%
-- Assessment results spanning both terms
-- Issues: mixed date formats, inconsistent subject names, duplicates, NULLs, JSON with variable structure
CREATE OR REPLACE TABLE bronze.assessments AS
SELECT * FROM VALUES
  -- Autumn 2024 assessments - clean-ish
  (1,  'P001', 100001, 'Mathematics',  72, 'B',  '2024-10-15', 'Autumn 2024', '{"teacher": "Mr Adams", "moderated": true, "method": "written_exam"}'),
  (2,  'P001', 100001, 'English',      85, 'A',  '2024-10-15', 'Autumn 2024', '{"teacher": "Ms Baker", "moderated": true, "method": "coursework"}'),
  (3,  'P002', 100001, 'Mathematics',  58, 'C',  '2024-10-15', 'Autumn 2024', '{"teacher": "Mr Adams", "moderated": true, "method": "written_exam"}'),
  (4,  'P002', 100001, 'English',      62, 'C',  '2024-10-15', 'Autumn 2024', '{"teacher": "Ms Baker", "moderated": false, "method": "coursework"}'),
  (5,  'P003', 100002, 'Mathematics',  91, 'A',  '2024-10-16', 'Autumn 2024', '{"teacher": "Mrs Carter", "moderated": true, "method": "written_exam"}'),
  (6,  'P003', 100002, 'English',      88, 'A',  '2024-10-16', 'Autumn 2024', '{"teacher": "Mr Dean", "moderated": true, "method": "coursework"}'),
  (7,  'P004', 100003, 'Mathematics',  45, 'D',  '2024-10-17', 'Autumn 2024', '{"teacher": "Ms Ellis", "moderated": true, "method": "written_exam"}'),
  (8,  'P004', 100003, 'English',      51, 'C',  '2024-10-17', 'Autumn 2024', '{"teacher": "Mr Ford", "moderated": false}'),
  (9,  'P005', 100004, 'Maths',        78, 'B',  '15/10/2024', 'Autumn 2024', '{"teacher": "Mrs Grant", "moderated": true, "method": "written_exam"}'),
  (10, 'P005', 100004, 'english',      82, 'A',  '15/10/2024', 'Autumn 2024', '{"teacher": "Mr Hunt", "moderated": true}'),
  (11, 'P006', 100005, 'MATHEMATICS',  67, 'B',  '2024-10-18', 'Autumn 2024', '{"teacher": "Ms Irving", "moderated": true, "method": "written_exam"}'),
  (12, 'P006', 100005, 'Science',      71, 'B',  '2024-10-18', 'Autumn 2024', '{"teacher": "Mr Jones", "moderated": true, "method": "practical"}'),
  (13, 'P007', 100006, 'Mathematics',  83, 'A',  '2024-10-18', 'Autumn 2024', '{"teacher": "Mrs Kelly", "moderated": true, "method": "written_exam"}'),
  (14, 'P008', 100007, 'Mathematics',  39, 'E',  '2024-10-19', 'Autumn 2024', '{"teacher": "Mr Lane", "moderated": false, "method": "written_exam"}'),
  (15, 'P009', 100008, 'Maths',        76, 'B',  '19/10/2024', 'Autumn 2024', '{"teacher": "Ms Moore"}'),
  (16, 'P010', 100009, 'Mathematics',  55, 'C',  '2024-10-20', 'Autumn 2024', '{"teacher": "Mr Nash", "moderated": true, "method": "written_exam"}'),
  -- Exact duplicate
  (1,  'P001', 100001, 'Mathematics',  72, 'B',  '2024-10-15', 'Autumn 2024', '{"teacher": "Mr Adams", "moderated": true, "method": "written_exam"}'),
  -- Spring 2025 assessments
  (17, 'P001', 100001, 'Mathematics',  78, 'B',  '2025-02-10', 'Spring 2025', '{"teacher": "Mr Adams", "moderated": true, "method": "written_exam", "improvement": true}'),
  (18, 'P001', 100001, 'English',      87, 'A',  '2025-02-10', 'Spring 2025', '{"teacher": "Ms Baker", "moderated": true, "method": "coursework", "improvement": true}'),
  (19, 'P002', 100001, 'math',         61, 'C',  '10/02/2025', 'Spring 2025', '{"teacher": "Mr Adams", "moderated": true, "method": "written_exam"}'),
  (20, 'P002', 100001, 'English',      65, 'C',  '2025-02-10', 'Spring 2025', '{"teacher": "Ms Baker", "moderated": true, "method": "coursework"}'),
  (21, 'P003', 100002, 'Mathematics',  93, 'A*', '2025-02-11', 'Spring 2025', '{"teacher": "Mrs Carter", "moderated": true, "method": "written_exam", "improvement": true}'),
  (22, 'P003', 100002, 'English',      90, 'A',  '2025-02-11', 'Spring 2025', '{"teacher": "Mr Dean", "moderated": true, "method": "coursework", "improvement": true}'),
  -- P004 moved school but assessment still references old closed school
  (23, 'P004', 100003, 'Mathematics',  48, 'D',  '2025-02-12', 'Spring 2025', '{"teacher": "Ms Ellis", "moderated": false, "method": "written_exam"}'),
  (24, 'P005', 100004, 'Mathematics',  81, 'A',  '2025-02-12', 'Spring 2025', '{"teacher": "Mrs Grant", "moderated": true, "method": "written_exam", "improvement": true}'),
  (25, 'P006', 100005, 'mathematics',  70, 'B',  '2025-02-13', 'Spring 2025', '{"teacher": "Ms Irving", "moderated": true, "method": "written_exam"}'),
  (26, 'P007', 100006, 'Mathematics',  86, 'A',  '2025-02-13', 'Spring 2025', '{"teacher": "Mrs Kelly", "moderated": true, "method": "written_exam", "improvement": true}'),
  (27, 'P008', 100007, 'Mathematics',  42, 'D',  '2025-02-14', 'Spring 2025', '{"teacher": "Mr Lane", "moderated": true, "method": "written_exam"}'),
  (28, 'P009', 100008, 'Maths',        79, 'B',  '14/02/2025', 'Spring 2025', '{"teacher": "Ms Moore", "moderated": true}'),
  (29, 'P010', 100009, 'Mathematics',  59, 'C',  '2025-02-15', 'Spring 2025', '{"teacher": "Mr Nash", "moderated": true, "method": "written_exam"}'),
  -- Assessment for orphaned pupil
  (30, 'P019', 999999, 'Mathematics',  64, 'C',  '2025-02-15', 'Spring 2025', '{"teacher": "Unknown", "moderated": false}'),
  -- NULL score and grade
  (31, 'P011', 100010, 'Mathematics',  NULL, NULL,'2025-02-15', 'Spring 2025', '{"teacher": "Mr Owen", "moderated": false, "notes": "Absent - illness"}'),
  -- Duplicate with conflicting score (natural key: assessment_id)
  (24, 'P005', 100004, 'Mathematics',  79, 'B',  '2025-02-12', 'Spring 2025', '{"teacher": "Mrs Grant", "moderated": false, "method": "written_exam"}')
AS t(assessment_id, pupil_id, school_urn, subject, score, grade, assessment_date, term, metadata_json);

-- %%
-- Attendance data: a single combined table with both terms
-- Issues: inconsistent status codes, mixed date formats, orphaned refs, NULLs, JSON session detail
CREATE OR REPLACE TABLE bronze.attendance AS
WITH date_range AS (
  -- Generate school days for Autumn term (Sep-Dec 2024) and Spring term (Jan-Mar 2025)
  SELECT explode(sequence(
    to_date('2024-09-02'), to_date('2025-03-28'), interval 1 day
  )) AS attendance_date
),
school_days AS (
  SELECT attendance_date
  FROM date_range
  WHERE dayofweek(attendance_date) BETWEEN 2 AND 6  -- Monday to Friday
    AND attendance_date NOT BETWEEN '2024-10-28' AND '2024-11-01' -- Half term
    AND attendance_date NOT BETWEEN '2024-12-23' AND '2025-01-03' -- Christmas
    AND attendance_date NOT BETWEEN '2025-02-17' AND '2025-02-21' -- Half term
),
pupil_list AS (
  SELECT * FROM VALUES
    ('P001'), ('P002'), ('P003'), ('P004'), ('P005'),
    ('P006'), ('P007'), ('P008'), ('P009'), ('P010'),
    ('P011'), ('P012'), ('P013'), ('P014'), ('P015'),
    ('P016'), ('P017'), ('P018'), ('P019'), ('P020')
  AS t(pupil_id)
),
cross_joined AS (
  SELECT p.pupil_id, s.attendance_date
  FROM pupil_list p
  CROSS JOIN school_days s
),
with_status AS (
  SELECT
    pupil_id,
    attendance_date,
    -- Generate realistic but messy attendance codes
    CASE
      -- Most pupils present most days
      WHEN abs(hash(concat(pupil_id, cast(attendance_date AS STRING)))) % 100 < 85 THEN
        CASE WHEN abs(hash(concat('am', pupil_id, cast(attendance_date AS STRING)))) % 20 = 0 THEN 'present'  -- inconsistent: lowercase
             WHEN abs(hash(concat('var', pupil_id, cast(attendance_date AS STRING)))) % 30 = 0 THEN 'P'       -- code variant
             ELSE 'Present'
        END
      WHEN abs(hash(concat(pupil_id, cast(attendance_date AS STRING)))) % 100 < 92 THEN
        CASE WHEN abs(hash(concat('ill', pupil_id, cast(attendance_date AS STRING)))) % 3 = 0 THEN 'Illness'
             WHEN abs(hash(concat('ill2', pupil_id, cast(attendance_date AS STRING)))) % 3 = 1 THEN 'ill'
             ELSE 'I'  -- code variant
        END
      WHEN abs(hash(concat(pupil_id, cast(attendance_date AS STRING)))) % 100 < 96 THEN 'Authorised Absence'
      WHEN abs(hash(concat(pupil_id, cast(attendance_date AS STRING)))) % 100 < 98 THEN
        CASE WHEN abs(hash(concat('unauth', pupil_id, cast(attendance_date AS STRING)))) % 2 = 0 THEN 'Unauthorised'
             ELSE 'U'  -- code variant
        END
      ELSE
        CASE WHEN abs(hash(concat('null', pupil_id, cast(attendance_date AS STRING)))) % 3 = 0 THEN NULL
             WHEN abs(hash(concat('null2', pupil_id, cast(attendance_date AS STRING)))) % 3 = 1 THEN ''
             ELSE 'N/A'
        END
    END AS attendance_status,
    CASE
      WHEN abs(hash(concat('fmt', pupil_id, cast(attendance_date AS STRING)))) % 5 = 0
        THEN date_format(attendance_date, 'dd/MM/yyyy')    -- UK format variant
      WHEN abs(hash(concat('fmt2', pupil_id, cast(attendance_date AS STRING)))) % 7 = 0
        THEN date_format(attendance_date, 'MM-dd-yyyy')    -- US format variant
      ELSE cast(attendance_date AS STRING)                   -- ISO format
    END AS date_recorded,
    CASE
      WHEN abs(hash(concat('sess', pupil_id, cast(attendance_date AS STRING)))) % 4 = 0
        THEN concat('{"am": "', 
          CASE WHEN abs(hash(concat('am_s', pupil_id, cast(attendance_date AS STRING)))) % 10 < 8 THEN 'Present' ELSE 'Absent' END,
          '", "pm": "',
          CASE WHEN abs(hash(concat('pm_s', pupil_id, cast(attendance_date AS STRING)))) % 10 < 9 THEN 'Present' ELSE 'Absent' END,
          '", "late_arrival": ', 
          CASE WHEN abs(hash(concat('late', pupil_id, cast(attendance_date AS STRING)))) % 8 = 0 THEN 'true' ELSE 'false' END,
          '}')
      ELSE NULL
    END AS session_json
  FROM cross_joined
)
SELECT * FROM with_status;

-- %%
-- Verify what we've created
SELECT 'schools_autumn_2024' AS table_name, COUNT(*) AS row_count FROM bronze.schools_autumn_2024
UNION ALL
SELECT 'schools_spring_2025', COUNT(*) FROM bronze.schools_spring_2025
UNION ALL
SELECT 'schools_summer_2025', COUNT(*) FROM bronze.schools_summer_2025
UNION ALL
SELECT 'schools_autumn_2025', COUNT(*) FROM bronze.schools_autumn_2025
UNION ALL
SELECT 'pupils_autumn_2024', COUNT(*) FROM bronze.pupils_autumn_2024
UNION ALL
SELECT 'pupils_spring_2025', COUNT(*) FROM bronze.pupils_spring_2025
UNION ALL
SELECT 'pupils_summer_2025', COUNT(*) FROM bronze.pupils_summer_2025
UNION ALL
SELECT 'pupils_autumn_2025', COUNT(*) FROM bronze.pupils_autumn_2025
UNION ALL
SELECT 'assessments', COUNT(*) FROM bronze.assessments
UNION ALL
SELECT 'attendance', COUNT(*) FROM bronze.attendance
ORDER BY table_name;

-- %% [markdown]
-- ## Export tables to CSV
--
-- Write each table out to a CSV file in the `resources/bronze` folder of this repository so that the data can be used without requiring access to the catalog.

-- %%
%python
import os

# Derive base_path from the notebook's own location for portability
notebook_path = dbutils.notebook.entry_point.getDbutils().notebook().getContext().notebookPath().get()
base_path = f"/Workspace{os.path.dirname(notebook_path)}"

print(f"Exporting to: {base_path}")
os.makedirs(base_path, exist_ok=True)

tables = [
    "schools_autumn_2024",
    "schools_spring_2025",
    "schools_summer_2025",
    "schools_autumn_2025",
    "pupils_autumn_2024",
    "pupils_spring_2025",
    "pupils_summer_2025",
    "pupils_autumn_2025",
    "assessments",
    "attendance",
]

for table_name in tables:
    df = spark.table(f"bronze.{table_name}")
    pdf = df.toPandas()
    out_file = os.path.join(base_path, f"{table_name}.csv")
    pdf.to_csv(out_file, index=False)
    print(f"{table_name}: {len(pdf)} rows -> {out_file}")

print("\nAll tables exported.")
